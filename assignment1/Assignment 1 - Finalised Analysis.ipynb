# %% [markdown]
# # Useful function for generating xtable

# %%
print.summary.lm.xtable <- function (x, digits = max(3, getOption("digits") - 3), symbolic.cor = x$symbolic.cor, 
    signif.stars = getOption("show.signif.stars"), ...) 
{

if(!require(xtable)) stop("This function requires the package 'xtable' - please make sure you get it")


cat("\\begin{verbatim}")

    cat("\nCall:\n", paste(deparse(x$call), sep = "\n", collapse = "\n"), 
        "\n\n", sep = "")
    resid <- x$residuals
    df <- x$df
    rdf <- df[2L]
    cat(if (!is.null(x$w) && diff(range(x$w))) 
        "Weighted ", "Residuals:\n", sep = "")
    if (rdf > 5L) {
        nam <- c("Min", "1Q", "Median", "3Q", "Max")
        rq <- if (length(dim(resid)) == 2L) 
            structure(apply(t(resid), 1L, quantile), dimnames = list(nam, 
                dimnames(resid)[[2L]]))
        else {
            zz <- zapsmall(quantile(resid), digits + 1)
            structure(zz, names = nam)
        }
        print(rq, digits = digits, ...)
    }
    else if (rdf > 0L) {
        print(resid, digits = digits, ...)
    }
    else {
        cat("ALL", df[1L], "residuals are 0: no residual degrees of freedom!\n")
    }

cat("\\end{verbatim}")

print(xtable(x),   latex.environments = "left") # x is a summary of some lm object

cat("\\begin{verbatim}")
    cat("Residual standard error:", format(signif(x$sigma, 
        digits)), "on", rdf, "degrees of freedom\n")
    if (nzchar(mess <- naprint(x$na.action))) 
        cat("  (", mess, ")\n", sep = "")
    if (!is.null(x$fstatistic)) {
        cat("Multiple R-squared:", formatC(x$r.squared, digits = digits))
        cat(",\tAdjusted R-squared:", formatC(x$adj.r.squared, 
            digits = digits), "\nF-statistic:", formatC(x$fstatistic[1L], 
            digits = digits), "on", x$fstatistic[2L], "and", 
            x$fstatistic[3L], "DF,  p-value:", format.pval(pf(x$fstatistic[1L], 
                x$fstatistic[2L], x$fstatistic[3L], lower.tail = FALSE), 
                digits = digits), "\n")
    }
    correl <- x$correlation
    if (!is.null(correl)) {
        p <- NCOL(correl)
        if (p > 1L) {
            cat("\nCorrelation of Coefficients:\n")
            if (is.logical(symbolic.cor) && symbolic.cor) {
                print(symnum(correl, abbr.colnames = NULL))
            }
            else {
                correl <- format(round(correl, 2), nsmall = 2, 
                  digits = digits)
                correl[!lower.tri(correl)] <- ""
                print(correl[-1, -p, drop = FALSE], quote = FALSE)
            }
        }
    }
    cat("\n")
cat("\\end{verbatim}")
    invisible(x)
}

# %% [markdown]
# # Relevant Packages
#
# - `ggplot2` for visualization
# - `olsrr` for ols_step_all_possible() function

# %%
# install.packages("car", repos = "http://cran.us.r-project.org") 
# install.packages("ggplot2", repos = "http://cran.us.r-project.org")
# install.packages("ppcor", repos = "http://cran.us.r-project.org") 
# install.packages("olsrr", repos = "http://cran.us.r-project.org") 
# install.packages("GGally", repos = "http://cran.us.r-project.org") 
# install.packages("grid", repos = "http://cran.us.r-project.org") 
# install.packages("gridExtra", repos = "http://cran.us.r-project.org") 
# install.packages("DT", repos = "http://cran.us.r-project.org") 
install.packages("texreg", repos = "http://cran.us.r-project.org") 
# install.packages("s", repos = "http://cran.us.r-project.org")
# Out:
# Installing package into 'C:/Users/emara/Documents/R/win-library/3.4'
# (as 'lib' is unspecified)
# package 'texreg' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\emara\AppData\Local\Temp\Rtmp6fv4O1\downloaded_packages

# %% [markdown]
# # Load libraries and dataset

# %%
library(ggplot2)
library(datasets)
library(DT)
library(xtable)
library(texreg)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.4.4"Warning message:
# "package 'DT' was built under R version 3.4.4"Warning message:
# "package 'xtable' was built under R version 3.4.4"Warning message:
# "package 'texreg' was built under R version 3.4.4"Version:  1.36.23
# Date:     2017-03-03
# Author:   Philip Leifeld (University of Glasgow)
#
# Please cite the JSS article in your publications -- see citation("texreg").

# %%
data(LifeCycleSavings)

# %% [markdown]
# # Understanding the dataset
#
# We will first look at the description to understand to get an intuitive understanding of the dataset. Then we will examine the data types of each column in the dataframe.

# %%
help(LifeCycleSavings)

# %% [markdown]
# At the very least, we now know that the target variable is `sr`, which stands for the aggregated *savings ratio* of citizens in a  country. After some quick googling, we can easily find a formal definition
#
# \begin{equation*}
# savingsRatio = \frac{amountSaved}{disposableIncome}
# \end{equation*}
#
# The explanatory variables are `pop15`, `pop75`, `dpi` and `ddpi`.
#
# - `dpi` stands for *disposable income*, which is defined as *income remaining after deduction of taxes and social security charges, available to be spent or saved as one wishes*
# - `ddpi` is the percentage of growth of *disposable income* over 40 years
# - `pop15` stands for percentage of population under the age of 15
# - `pop75` stands for percentage of population over the age of 75

# %%
str(LifeCycleSavings)
# Out:
# 'data.frame':	50 obs. of  5 variables:
#  $ sr   : num  11.43 12.07 13.17 5.75 12.88 ...
#  $ pop15: num  29.4 23.3 23.8 41.9 42.2 ...
#  $ pop75: num  2.87 4.41 4.43 1.67 0.83 2.85 1.34 0.67 1.06 1.14 ...
#  $ dpi  : num  2330 1508 2108 189 728 ...
#  $ ddpi : num  2.87 3.93 3.82 0.22 4.56 2.43 2.67 6.51 3.08 2.8 ...

# %% [markdown]
# Target variable and explanatory variables are all `numeric` type. This is great because it means we do not need to handle categorical variables.

# %%
# Take a look at the first few rows of the dataframe
head(LifeCycleSavings)
# Out:
#           sr    pop15 pop75 dpi     ddpi
# Australia 11.43 29.35 2.87  2329.68 2.87
# Austria   12.07 23.32 4.41  1507.99 3.93
# Belgium   13.17 23.80 4.43  2108.47 3.82
# Bolivia    5.75 41.89 1.67   189.13 0.22
# Brazil    12.88 42.19 0.83   728.47 4.56
# Canada     8.79 31.72 2.85  2982.88 2.43

# %%
# Take a look at the numbers in each column
LifeCycleSavings[,1]
LifeCycleSavings[,2]
LifeCycleSavings[,3]
LifeCycleSavings[,4]
LifeCycleSavings[,5]
# Out:
#  [1] 11.43 12.07 13.17  5.75 12.88  8.79  0.60 11.90  4.98 10.78 16.85  3.59
# [13] 11.24 12.64 12.55 10.67  3.01  7.70  1.27  9.00 11.34 14.28 21.10  3.98
# [25] 10.35 15.48 10.25 14.65 10.67  7.30  4.44  2.02 12.70 12.78 12.49 11.14
# [37] 13.30 11.77  6.86 14.13  5.13  2.81  7.81  7.56  9.22 18.56  7.72  9.24
# [49]  8.89  4.71
#  [1] 29.35 23.32 23.80 41.89 42.19 31.72 39.74 44.75 46.64 47.64 24.42 46.31
# [13] 27.84 25.06 23.31 25.62 46.05 47.32 34.03 41.31 31.16 24.52 27.01 41.74
# [25] 21.80 32.54 25.95 24.71 32.61 45.04 43.56 41.18 44.19 46.26 28.96 31.94
# [37] 31.92 27.74 21.44 23.49 43.42 46.12 23.27 29.81 46.40 45.25 41.12 28.13
# [49] 43.69 47.20
#  [1] 2.87 4.41 4.43 1.67 0.83 2.85 1.34 0.67 1.06 1.14 3.93 1.19 2.37 4.70 3.35
# [16] 3.10 0.87 0.58 3.08 0.96 4.19 3.48 1.91 0.91 3.73 2.47 3.67 3.25 3.17 1.21
# [31] 1.20 1.05 1.28 1.12 2.85 2.28 1.52 2.87 4.54 3.73 1.08 1.21 4.46 3.43 0.90
# [46] 0.56 1.73 2.72 2.07 0.66
#  [1] 2329.68 1507.99 2108.47  189.13  728.47 2982.88  662.86  289.52  276.65
# [10]  471.24 2496.53  287.77 1681.25 2213.82 2457.12  870.85  289.71  232.44
# [19] 1900.10   88.94 1139.95 1390.00 1257.28  207.68 2449.39  601.05 2231.03
# [28] 1740.70 1487.52  325.54  568.56  220.56  400.06  152.01  579.51  651.11
# [37]  250.96  768.79 3299.49 2630.96  389.66  249.87 1813.93 4001.89  813.39
# [46]  138.33  380.47  766.54  123.58  242.69
#  [1]  2.87  3.93  3.82  0.22  4.56  2.43  2.67  6.51  3.08  2.80  3.99  2.19
# [13]  4.32  4.52  3.44  6.28  1.48  3.19  1.12  1.54  2.99  3.54  8.21  5.81
# [25]  1.57  8.12  3.62  7.66  1.76  2.48  3.61  1.03  0.67  2.00  7.48  2.19
# [37]  2.00  4.35  3.01  2.70  2.96  1.13  2.01  2.45  0.53  5.14 10.23  1.88
# [49] 16.71  5.08

# %% [markdown]
# No `NaN` or 'weird' numbers at this point, good sign.

# %% [markdown]
# # Initial Data Analysis
#
# We will start exploring the data by looking at the scatter plot.

# %%
# bivariate relations

# using base graphics
# pairs( ~ sr + pop15 + pop75 + dpi + ddpi, data=LifeCycleSavings)

# using ggally
library(GGally)
ggpairs(LifeCycleSavings, mapping = aes(color = sr), upper=list(continuous = "points", combo = "box"))

# Saving the plot
pdf("LifeCycleSavings_scatterMatrix.pdf", height = 7, width = 7)
plot = ggpairs(LifeCycleSavings, mapping = aes(color = sr), upper=list(continuous = "points", combo = "box"))
print(plot)
dev.off()
# Out:
# Warning message:
# "package 'GGally' was built under R version 3.4.4"
# png
#   2
# plot without title

# %% [markdown]
# We can easily spot a strong negative correlation between `pop15` and `pop75`. Is this intuitive? Yes! If a country has high proportion of citizens above the age of 75, it makes sense that the birth rates will be low.
#
# How strong is it? Let's look at the variance-covariance and correlation matrices.

# %%
# cov(LifeCycleSavings[c(1,2,3,4,5)])
# cor(LifeCycleSavings[c(1,2,3,4,5)])

# using ggplot2
ggcorr(LifeCycleSavings[c(1,2,3,4,5)], palette = "RdGy", label = TRUE, label_round = 2)

# Saving the plot
# pdf("LifeCycleSavings_correlationMatrix.pdf", height = 7, width = 7)
# plot = ggcorr(LifeCycleSavings[c(1,2,3,4,5)], palette = "RdGy", label = TRUE, label_round = 2)
# print(plot)
# dev.off()
# Out:
# plot without title

# %% [markdown]
# Indeed, `pop15` and `pop75` has a negative correlation of -0.91.
# There seems to be a strong correlation between `pop75` and `dpi` as well. This also makes sense intuitively.
#
# Now, we move on to looking at the partial correlation matrix.

# %%
ppcor::pcor(LifeCycleSavings[c(1,2,3,4,5)])$estimate

# for xtable format in latex
print(xtable(ppcor::pcor(LifeCycleSavings[c(1,2,3,4,5)])$estimate))
print(xtable(cor(LifeCycleSavings[c(1,2,3,4,5)])))
# Out:
#       sr          pop15       pop75      dpi         ddpi
# sr     1.00000000 -0.42928891 -0.2266447 -0.05386004  0.29722011
# pop15 -0.42928891  1.00000000 -0.7705525 -0.18537256  0.03923169
# pop75 -0.22664467 -0.77055252  1.0000000  0.34476850  0.11825311
# dpi   -0.05386004 -0.18537256  0.3447685  1.00000000 -0.22757638
# ddpi   0.29722011  0.03923169  0.1182531 -0.22757638  1.00000000
# % latex table generated in R 3.4.3 by xtable 1.8-2 package
# % Mon Apr 09 03:47:01 2018
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrrr}
#   \hline
#  & sr & pop15 & pop75 & dpi & ddpi \\
#   \hline
# sr & 1.00 & -0.43 & -0.23 & -0.05 & 0.30 \\
#   pop15 & -0.43 & 1.00 & -0.77 & -0.19 & 0.04 \\
#   pop75 & -0.23 & -0.77 & 1.00 & 0.34 & 0.12 \\
#   dpi & -0.05 & -0.19 & 0.34 & 1.00 & -0.23 \\
#   ddpi & 0.30 & 0.04 & 0.12 & -0.23 & 1.00 \\
#    \hline
# \end{tabular}
# \end{table}
# % latex table generated in R 3.4.3 by xtable 1.8-2 package
# % Mon Apr 09 03:47:01 2018
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrrr}
#   \hline
#  & sr & pop15 & pop75 & dpi & ddpi \\
#   \hline
# sr & 1.00 & -0.46 & 0.32 & 0.22 & 0.30 \\
#   pop15 & -0.46 & 1.00 & -0.91 & -0.76 & -0.05 \\
#   pop75 & 0.32 & -0.91 & 1.00 & 0.79 & 0.03 \\
#   dpi & 0.22 & -0.76 & 0.79 & 1.00 & -0.13 \\
#   ddpi & 0.30 & -0.05 & 0.03 & -0.13 & 1.00 \\
#    \hline
# \end{tabular}
# \end{table}

# %% [markdown]
# # Modeling
#
# ### Models with first order terms only

# %%
models = new.env()

# linear model
models.baseline <- lm(sr ~ pop15 + pop75 + dpi + ddpi, data = LifeCycleSavings)
summary(models.baseline)

# for xtable format in latex
print.summary.lm.xtable(summary(models.baseline))
# Out:
# Call:
# lm(formula = sr ~ pop15 + pop75 + dpi + ddpi, data = LifeCycleSavings)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.2422 -2.6857 -0.2488  2.4280  9.7509
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) 28.5660865  7.3545161   3.884 0.000334 ***
# pop15       -0.4611931  0.1446422  -3.189 0.002603 **
# pop75       -1.6914977  1.0835989  -1.561 0.125530
# dpi         -0.0003369  0.0009311  -0.362 0.719173
# ddpi         0.4096949  0.1961971   2.088 0.042471 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 3.803 on 45 degrees of freedom
# Multiple R-squared:  0.3385,	Adjusted R-squared:  0.2797
# F-statistic: 5.756 on 4 and 45 DF,  p-value: 0.0007904
# \begin{verbatim}
# Call:
# lm(formula = sr ~ pop15 + pop75 + dpi + ddpi, data = LifeCycleSavings)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.2422 -2.6857 -0.2488  2.4280  9.7509
# \end{verbatim}% latex table generated in R 3.4.3 by xtable 1.8-2 package
# % Mon Apr 09 03:34:52 2018
# \begin{table}[ht]
# \begin{left}
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Pr($>$$|$t$|$) \\
#   \hline
# (Intercept) & 28.5661 & 7.3545 & 3.88 & 0.0003 \\
#   pop15 & -0.4612 & 0.1446 & -3.19 & 0.0026 \\
#   pop75 & -1.6915 & 1.0836 & -1.56 & 0.1255 \\
#   dpi & -0.0003 & 0.0009 & -0.36 & 0.7192 \\
#   ddpi & 0.4097 & 0.1962 & 2.09 & 0.0425 \\
#    \hline
# \end{tabular}
# \end{left}
# \end{table}
# \begin{verbatim}Residual standard error: 3.803 on 45 degrees of freedom
# Multiple R-squared: 0.3385,	Adjusted R-squared: 0.2797
# F-statistic: 5.756 on 4 and 45 DF,  p-value: 0.0007904
#
# \end{verbatim}

# %%
# backward elimination on baseline
models.baseline_backward <- step(models.baseline, direction = 'backward')
# Out:
# Start:  AIC=138.3
# sr ~ pop15 + pop75 + dpi + ddpi
#
#         Df Sum of Sq    RSS    AIC
# - dpi    1     1.893 652.61 136.45
# <none>               650.71 138.30
# - pop75  1    35.236 685.95 138.94
# - ddpi   1    63.054 713.77 140.93
# - pop15  1   147.012 797.72 146.49
#
# Step:  AIC=136.45
# sr ~ pop15 + pop75 + ddpi
#
#         Df Sum of Sq    RSS    AIC
# <none>               652.61 136.45
# - pop75  1    47.946 700.55 137.99
# - ddpi   1    73.562 726.17 139.79
# - pop15  1   145.789 798.40 144.53

# %%
# forward selection on baseline
models.baseline_forward = step(lm(sr ~ 1, data=LifeCycleSavings), direction='forward', scope=~ pop15 + pop75 + dpi + ddpi)

print.summary.lm.xtable(summary(models.baseline_forward))
# Out:
# Start:  AIC=150.96
# sr ~ 1
#
#         Df Sum of Sq    RSS    AIC
# + pop15  1   204.118 779.51 141.33
# + pop75  1    98.545 885.08 147.68
# + ddpi   1    91.374 892.25 148.09
# + dpi    1    47.763 935.87 150.47
# <none>               983.63 150.96
#
# Step:  AIC=141.33
# sr ~ pop15
#
#         Df Sum of Sq    RSS    AIC
# + ddpi   1    78.959 700.55 137.99
# + pop75  1    53.343 726.17 139.79
# + dpi    1    35.387 744.12 141.01
# <none>               779.51 141.33
#
# Step:  AIC=137.99
# sr ~ pop15 + ddpi
#
#         Df Sum of Sq    RSS    AIC
# + pop75  1    47.946 652.61 136.45
# <none>               700.55 137.99
# + dpi    1    14.603 685.95 138.94
#
# Step:  AIC=136.45
# sr ~ pop15 + ddpi + pop75
#
#        Df Sum of Sq    RSS    AIC
# <none>              652.61 136.45
# + dpi   1    1.8932 650.71 138.30
# \begin{verbatim}
# Call:
# lm(formula = sr ~ pop15 + ddpi + pop75, data = LifeCycleSavings)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.2539 -2.6159 -0.3913  2.3344  9.7070
# \end{verbatim}% latex table generated in R 3.4.3 by xtable 1.8-2 package
# % Mon Apr 09 03:38:47 2018
# \begin{table}[ht]
# \begin{left}
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Pr($>$$|$t$|$) \\
#   \hline
# (Intercept) & 28.1247 & 7.1838 & 3.92 & 0.0003 \\
#   pop15 & -0.4518 & 0.1409 & -3.21 & 0.0025 \\
#   ddpi & 0.4278 & 0.1879 & 2.28 & 0.0275 \\
#   pop75 & -1.8354 & 0.9984 & -1.84 & 0.0725 \\
#    \hline
# \end{tabular}
# \end{left}
# \end{table}
# \begin{verbatim}Residual standard error: 3.767 on 46 degrees of freedom
# Multiple R-squared: 0.3365,	Adjusted R-squared: 0.2933
# F-statistic: 7.778 on 3 and 46 DF,  p-value: 0.0002646
#
# \end{verbatim}

# %% [markdown]
# Both forward selection and backward selection returns the same optimal model.

# %%
# Compute all possible models
all_possible_first_order_models = olsrr::ols_step_all_possible(models.baseline)
# all_possible_first_order_models

# for xtable format in latex
all_possible_first_order_models = all_possible_first_order_models[ , c("n","predictors", "rsquare", "adjr", "aic", "sbic")]
print(xtable(all_possible_first_order_models))
# Out:
# % latex table generated in R 3.4.3 by xtable 1.8-2 package
# % Mon Apr 09 03:35:02 2018
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrlrrrr}
#   \hline
#  & n & predictors & rsquare & adjr & aic & sbic \\
#   \hline
# 1 &   1 & pop15 & 0.21 & 0.19 & 285.23 & 143.03 \\
#   2 &   1 & pop75 & 0.10 & 0.08 & 291.58 & 148.88 \\
#   4 &   1 & ddpi & 0.09 & 0.07 & 291.98 & 149.26 \\
#   3 &   1 & dpi & 0.05 & 0.03 & 294.37 & 151.46 \\
#   7 &   2 & pop15 ddpi & 0.29 & 0.26 & 281.89 & 140.18 \\
#   5 &   2 & pop15 pop75 & 0.26 & 0.23 & 283.68 & 141.76 \\
#   6 &   2 & pop15 dpi & 0.24 & 0.21 & 284.90 & 142.84 \\
#   9 &   2 & pop75 ddpi & 0.19 & 0.15 & 288.42 & 145.94 \\
#   10 &   2 & dpi ddpi & 0.16 & 0.13 & 290.04 & 147.38 \\
#   8 &   2 & pop75 dpi & 0.10 & 0.06 & 293.46 & 150.41 \\
#   12 &   3 & pop15 pop75 ddpi & 0.34 & 0.29 & 280.34 & 139.29 \\
#   13 &   3 & pop15 dpi ddpi & 0.30 & 0.26 & 282.83 & 141.37 \\
#   11 &   3 & pop15 pop75 dpi & 0.27 & 0.23 & 284.82 & 143.03 \\
#   14 &   3 & pop75 dpi ddpi & 0.19 & 0.14 & 290.38 & 147.72 \\
#   15 &   4 & pop15 pop75 dpi ddpi & 0.34 & 0.28 & 282.20 & 141.39 \\
#    \hline
# \end{tabular}
# \end{table}

# %%
# select model with max adjusted r^2, lowest aic, and lowest bic
which.max(all_possible_first_order_models$adjr)
which.min(all_possible_first_order_models$aic)
which.min(all_possible_first_order_models$sbic)
# Out:
# [1] 11
# [1] 11
# [1] 11

# %% [markdown]
# - AIC = −2log(L) + 2K, where K is the number of parameters, L is the likelihood function.
# - BIC = (log(n))k + 2log(L), where n is the number of data points, k is the number of parameters of the model
#
# When we try to maximize all three criteria, we end up with the same model! This is a very good sign that the chosen model is optimal.

# %%
all_possible_first_order_models[11, ]
# Out:
#    n predictors       rsquare   adjr     aic      sbic
# 12 3 pop15 pop75 ddpi 0.3365317 0.293262 280.3414 139.2874

# %% [markdown]
# This is the same as the one we got from backward & forward selection.

# %%
models.baseline_optimal = lm(sr ~ (pop15 + pop75 + ddpi), data = LifeCycleSavings)
summary(models.baseline_optimal)

# xtable
print.summary.lm.xtable(summary(models.baseline_optimal))
# Out:
# Call:
# lm(formula = sr ~ (pop15 + pop75 + ddpi), data = LifeCycleSavings)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.2539 -2.6159 -0.3913  2.3344  9.7070
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  28.1247     7.1838   3.915 0.000297 ***
# pop15        -0.4518     0.1409  -3.206 0.002452 **
# pop75        -1.8354     0.9984  -1.838 0.072473 .
# ddpi          0.4278     0.1879   2.277 0.027478 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 3.767 on 46 degrees of freedom
# Multiple R-squared:  0.3365,	Adjusted R-squared:  0.2933
# F-statistic: 7.778 on 3 and 46 DF,  p-value: 0.0002646
# \begin{verbatim}
# Call:
# lm(formula = sr ~ (pop15 + pop75 + ddpi), data = LifeCycleSavings)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.2539 -2.6159 -0.3913  2.3344  9.7070
# \end{verbatim}% latex table generated in R 3.4.3 by xtable 1.8-2 package
# % Mon Apr 09 03:35:05 2018
# \begin{table}[ht]
# \begin{left}
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Pr($>$$|$t$|$) \\
#   \hline
# (Intercept) & 28.1247 & 7.1838 & 3.92 & 0.0003 \\
#   pop15 & -0.4518 & 0.1409 & -3.21 & 0.0025 \\
#   pop75 & -1.8354 & 0.9984 & -1.84 & 0.0725 \\
#   ddpi & 0.4278 & 0.1879 & 2.28 & 0.0275 \\
#    \hline
# \end{tabular}
# \end{left}
# \end{table}
# \begin{verbatim}Residual standard error: 3.767 on 46 degrees of freedom
# Multiple R-squared: 0.3365,	Adjusted R-squared: 0.2933
# F-statistic: 7.778 on 3 and 46 DF,  p-value: 0.0002646
#
# \end{verbatim}

# %% [markdown]
# ### Models with second order terms

# %%
# linear model with interactions
models.second_order_baseline <- lm(sr ~ (pop15 + pop75 + dpi + ddpi)^2, data = LifeCycleSavings)
summary(models.second_order_baseline)

# xtable
print.summary.lm.xtable(summary(models.second_order_baseline))
# Out:
# Call:
# lm(formula = sr ~ (pop15 + pop75 + dpi + ddpi)^2, data = LifeCycleSavings)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.8162 -2.9265  0.1388  2.2292  9.6419
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  9.204e+00  1.877e+01   0.490    0.627
# pop15       -6.423e-02  3.785e-01  -0.170    0.866
# pop75        3.886e+00  4.809e+00   0.808    0.424
# dpi          3.200e-04  1.032e-02   0.031    0.975
# ddpi         1.126e+00  3.220e+00   0.350    0.728
# pop15:pop75 -9.288e-02  1.264e-01  -0.735    0.467
# pop15:dpi   -9.644e-07  2.266e-04  -0.004    0.997
# pop15:ddpi  -1.151e-02  6.328e-02  -0.182    0.857
# pop75:dpi   -8.923e-04  1.460e-03  -0.611    0.545
# pop75:ddpi  -2.863e-01  4.313e-01  -0.664    0.511
# dpi:ddpi     7.613e-04  7.277e-04   1.046    0.302
#
# Residual standard error: 3.851 on 39 degrees of freedom
# Multiple R-squared:  0.412,	Adjusted R-squared:  0.2612
# F-statistic: 2.733 on 10 and 39 DF,  p-value: 0.01195
# \begin{verbatim}
# Call:
# lm(formula = sr ~ (pop15 + pop75 + dpi + ddpi)^2, data = LifeCycleSavings)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.8162 -2.9265  0.1388  2.2292  9.6419
# \end{verbatim}% latex table generated in R 3.4.3 by xtable 1.8-2 package
# % Mon Apr 09 03:35:10 2018
# \begin{table}[ht]
# \begin{left}
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Pr($>$$|$t$|$) \\
#   \hline
# (Intercept) & 9.2038 & 18.7657 & 0.49 & 0.6266 \\
#   pop15 & -0.0642 & 0.3785 & -0.17 & 0.8661 \\
#   pop75 & 3.8865 & 4.8090 & 0.81 & 0.4239 \\
#   dpi & 0.0003 & 0.0103 & 0.03 & 0.9754 \\
#   ddpi & 1.1263 & 3.2196 & 0.35 & 0.7283 \\
#   pop15:pop75 & -0.0929 & 0.1264 & -0.73 & 0.4669 \\
#   pop15:dpi & -0.0000 & 0.0002 & -0.00 & 0.9966 \\
#   pop15:ddpi & -0.0115 & 0.0633 & -0.18 & 0.8566 \\
#   pop75:dpi & -0.0009 & 0.0015 & -0.61 & 0.5447 \\
#   pop75:ddpi & -0.2863 & 0.4313 & -0.66 & 0.5108 \\
#   dpi:ddpi & 0.0008 & 0.0007 & 1.05 & 0.3020 \\
#    \hline
# \end{tabular}
# \end{left}
# \end{table}
# \begin{verbatim}Residual standard error: 3.851 on 39 degrees of freedom
# Multiple R-squared: 0.412,	Adjusted R-squared: 0.2612
# F-statistic: 2.733 on 10 and 39 DF,  p-value: 0.01195
#
# \end{verbatim}

# %%
# backward elimination on baseline
models.second_order_baseline_backward_backward <- step(models.second_order_baseline, direction = 'backward')
summary(models.second_order_baseline_backward_backward)

# xtable
print.summary.lm.xtable(summary(models.second_order_baseline_backward_backward))
# Out:
# Start:  AIC=144.41
# sr ~ (pop15 + pop75 + dpi + ddpi)^2
#
#               Df Sum of Sq    RSS    AIC
# - pop15:dpi    1    0.0003 578.37 142.41
# - pop15:ddpi   1    0.4910 578.86 142.45
# - pop75:dpi    1    5.5364 583.91 142.89
# - pop75:ddpi   1    6.5316 584.90 142.97
# - pop15:pop75  1    8.0062 586.38 143.10
# - dpi:ddpi     1   16.2285 594.60 143.79
# <none>                     578.37 144.41
#
# Step:  AIC=142.41
# sr ~ pop15 + pop75 + dpi + ddpi + pop15:pop75 + pop15:ddpi +
#     pop75:dpi + pop75:ddpi + dpi:ddpi
#
#               Df Sum of Sq    RSS    AIC
# - pop15:ddpi   1    0.5108 578.88 140.45
# - pop75:ddpi   1    6.7381 585.11 140.99
# - pop75:dpi    1    8.3861 586.76 141.13
# - pop15:pop75  1    9.5161 587.89 141.23
# - dpi:ddpi     1   16.4076 594.78 141.81
# <none>                     578.37 142.41
#
# Step:  AIC=140.45
# sr ~ pop15 + pop75 + dpi + ddpi + pop15:pop75 + pop75:dpi + pop75:ddpi +
#     dpi:ddpi
#
#               Df Sum of Sq    RSS    AIC
# - pop75:ddpi   1     6.546 585.43 139.02
# - pop15:pop75  1     9.910 588.79 139.30
# - pop75:dpi    1    10.734 589.62 139.37
# <none>                     578.88 140.45
# - dpi:ddpi     1    44.067 622.95 142.12
#
# Step:  AIC=139.02
# sr ~ pop15 + pop75 + dpi + ddpi + pop15:pop75 + pop75:dpi + dpi:ddpi
#
#               Df Sum of Sq    RSS    AIC
# - pop75:dpi    1    10.168 595.60 137.88
# - pop15:pop75  1    12.249 597.68 138.05
# <none>                     585.43 139.02
# - dpi:ddpi     1    41.092 626.52 140.41
#
# Step:  AIC=137.88
# sr ~ pop15 + pop75 + dpi + ddpi + pop15:pop75 + dpi:ddpi
#
#               Df Sum of Sq    RSS    AIC
# - pop15:pop75  1     2.958 598.55 136.12
# <none>                     595.60 137.88
# - dpi:ddpi     1    45.223 640.82 139.54
#
# Step:  AIC=136.12
# sr ~ pop15 + pop75 + dpi + ddpi + dpi:ddpi
#
#            Df Sum of Sq    RSS    AIC
# - pop75     1    16.708 615.26 135.50
# <none>                  598.55 136.12
# - dpi:ddpi  1    52.158 650.71 138.30
# - pop15     1    63.923 662.48 139.20
#
# Step:  AIC=135.5
# sr ~ pop15 + dpi + ddpi + dpi:ddpi
#
#            Df Sum of Sq    RSS    AIC
# <none>                  615.26 135.50
# - pop15     1    58.171 673.43 138.02
# - dpi:ddpi  1    70.686 685.95 138.94
# Call:
# lm(formula = sr ~ pop15 + dpi + ddpi + dpi:ddpi, data = LifeCycleSavings)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.6393 -2.7889 -0.0436  2.5328 10.7488
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) 16.5287997  4.3729241   3.780 0.000459 ***
# pop15       -0.2023669  0.0981090  -2.063 0.044943 *
# dpi         -0.0027411  0.0011774  -2.328 0.024457 *
# ddpi         0.0462479  0.2439993   0.190 0.850521
# dpi:ddpi     0.0008171  0.0003593   2.274 0.027802 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 3.698 on 45 degrees of freedom
# Multiple R-squared:  0.3745,	Adjusted R-squared:  0.3189
# F-statistic: 6.736 on 4 and 45 DF,  p-value: 0.0002452
# \begin{verbatim}
# Call:
# lm(formula = sr ~ pop15 + dpi + ddpi + dpi:ddpi, data = LifeCycleSavings)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.6393 -2.7889 -0.0436  2.5328 10.7488
# \end{verbatim}% latex table generated in R 3.4.3 by xtable 1.8-2 package
# % Mon Apr 09 03:36:35 2018
# \begin{table}[ht]
# \begin{left}
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Pr($>$$|$t$|$) \\
#   \hline
# (Intercept) & 16.5288 & 4.3729 & 3.78 & 0.0005 \\
#   pop15 & -0.2024 & 0.0981 & -2.06 & 0.0449 \\
#   dpi & -0.0027 & 0.0012 & -2.33 & 0.0245 \\
#   ddpi & 0.0462 & 0.2440 & 0.19 & 0.8505 \\
#   dpi:ddpi & 0.0008 & 0.0004 & 2.27 & 0.0278 \\
#    \hline
# \end{tabular}
# \end{left}
# \end{table}
# \begin{verbatim}Residual standard error: 3.698 on 45 degrees of freedom
# Multiple R-squared: 0.3745,	Adjusted R-squared: 0.3189
# F-statistic: 6.736 on 4 and 45 DF,  p-value: 0.0002452
#
# \end{verbatim}

# %%
# forward selection on baseline
models.second_order_baseline_forward =
step(lm(sr ~ 1, data=LifeCycleSavings), direction='forward', scope=~ (pop15 + pop75 + dpi + ddpi)^2)
summary(models.second_order_baseline_forward)

# xtable
print.summary.lm.xtable(summary(models.second_order_baseline_forward))
# Out:
# Start:  AIC=150.96
# sr ~ 1
#
#         Df Sum of Sq    RSS    AIC
# + pop15  1   204.118 779.51 141.33
# + pop75  1    98.545 885.08 147.68
# + ddpi   1    91.374 892.25 148.09
# + dpi    1    47.763 935.87 150.47
# <none>               983.63 150.96
#
# Step:  AIC=141.33
# sr ~ pop15
#
#         Df Sum of Sq    RSS    AIC
# + ddpi   1    78.959 700.55 137.99
# + pop75  1    53.343 726.17 139.79
# + dpi    1    35.387 744.12 141.01
# <none>               779.51 141.33
#
# Step:  AIC=137.99
# sr ~ pop15 + ddpi
#
#              Df Sum of Sq    RSS    AIC
# + pop15:ddpi  1    59.206 641.35 135.58
# + pop75       1    47.946 652.61 136.45
# <none>                    700.55 137.99
# + dpi         1    14.603 685.95 138.94
#
# Step:  AIC=135.58
# sr ~ pop15 + ddpi + pop15:ddpi
#
#         Df Sum of Sq    RSS    AIC
# <none>               641.35 135.58
# + pop75  1   24.4133 616.93 135.64
# + dpi    1    3.8467 637.50 137.28
# Call:
# lm(formula = sr ~ pop15 + ddpi + pop15:ddpi, data = LifeCycleSavings)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.5198 -2.2376 -0.1007  2.1628 11.0307
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  7.59867    4.49133   1.692   0.0974 .
# pop15       -0.01520    0.11373  -0.134   0.8942
# ddpi         2.59309    1.05993   2.446   0.0183 *
# pop15:ddpi  -0.05465    0.02652  -2.061   0.0450 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 3.734 on 46 degrees of freedom
# Multiple R-squared:  0.348,	Adjusted R-squared:  0.3055
# F-statistic: 8.183 on 3 and 46 DF,  p-value: 0.00018
# \begin{verbatim}
# Call:
# lm(formula = sr ~ pop15 + ddpi + pop15:ddpi, data = LifeCycleSavings)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.5198 -2.2376 -0.1007  2.1628 11.0307
# \end{verbatim}% latex table generated in R 3.4.3 by xtable 1.8-2 package
# % Sun Apr 08 17:25:25 2018
# \begin{table}[ht]
# \begin{left}
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Pr($>$$|$t$|$) \\
#   \hline
# (Intercept) & 7.5987 & 4.4913 & 1.69 & 0.0974 \\
#   pop15 & -0.0152 & 0.1137 & -0.13 & 0.8942 \\
#   ddpi & 2.5931 & 1.0599 & 2.45 & 0.0183 \\
#   pop15:ddpi & -0.0546 & 0.0265 & -2.06 & 0.0450 \\
#    \hline
# \end{tabular}
# \end{left}
# \end{table}
# \begin{verbatim}Residual standard error: 3.734 on 46 degrees of freedom
# Multiple R-squared: 0.348,	Adjusted R-squared: 0.3055
# F-statistic: 8.183 on 3 and 46 DF,  p-value: 0.00018
#
# \end{verbatim}

# %%
# Computer all possible models
all_possible_second_order_models = olsrr::ols_step_all_possible(models.second_order_baseline)
all_possible_second_order_models
# Out:
#      mindex n
# 10    1     1
# 1     2     1
# 9     3     1
# 2     4     1
# 4     5     1
# 3     6     1
# 8     7     1
# 5     8     1
# 6     9     1
# 7    10     1
# 37   11     2
# 49   12     2
# 34   13     2
# 54   14     2
# 13   15     2
# 40   16     2
# 16   17     2
# 11   18     2
# 14   19     2
# 17   20     2
# 55   21     2
# 18   22     2
# 19   23     2
# 45   24     2
# 52   25     2
# 12   26     2
# 15   27     2
# 27   28     2
# 51   29     2
# 33   30     2
# ...  ...    ...
# 1009  994    8
# 986   995    8
# 1002  996    8
# 1006  997    8
# 988   998    8
# 970   999    8
# 997  1000    8
# 991  1001    8
# 974  1002    8
# 1004 1003    8
# 989  1004    8
# 979  1005    8
# 969  1006    8
# 968  1007    8
# 1012 1008    8
# 996  1009    8
# 978  1010    8
# 971  1011    8
# 983  1012    8
# 1017 1013    9
# 1020 1014    9
# 1022 1015    9
# 1016 1016    9
# 1019 1017    9
# 1015 1018    9
# 1014 1019    9
# 1018 1020    9
# 1021 1021    9
# 1013 1022    9
# 1023 1023   10
#      predictors
# 10   dpi:ddpi
# 1    pop15
# 9    pop75:ddpi
# 2    pop75
# 4    ddpi
# 3    dpi
# 8    pop75:dpi
# 5    pop15:pop75
# 6    pop15:dpi
# 7    pop15:ddpi
# 37   ddpi pop15:ddpi
# 49   pop15:dpi dpi:ddpi
# 34   dpi dpi:ddpi
# 54   pop75:dpi dpi:ddpi
# 13   pop15 ddpi
# 40   ddpi dpi:ddpi
# 16   pop15 pop15:ddpi
# 11   pop15 pop75
# 14   pop15 pop15:pop75
# 17   pop15 pop75:dpi
# 55   pop75:ddpi dpi:ddpi
# 18   pop15 pop75:ddpi
# 19   pop15 dpi:ddpi
# 45   pop15:pop75 dpi:ddpi
# 52   pop15:ddpi dpi:ddpi
# 12   pop15 dpi
# 15   pop15 pop15:dpi
# 27   pop75 dpi:ddpi
# 51   pop15:ddpi pop75:ddpi
# 33   dpi pop75:ddpi
# ...  ...
# 1009 pop75 dpi ddpi pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi
# 986  pop15 pop75 dpi pop15:pop75 pop15:dpi pop75:dpi pop75:ddpi dpi:ddpi
# 1002 pop15 dpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi
# 1006 pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi
# 988  pop15 pop75 dpi pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi
# 970  pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi dpi:ddpi
# 997  pop15 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi
# 991  pop15 pop75 ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi
# 974  pop15 pop75 dpi ddpi pop15:pop75 pop15:ddpi pop75:dpi pop75:ddpi
# 1004 pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi
# 989  pop15 pop75 ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi
# 979  pop15 pop75 dpi ddpi pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi
# 969  pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi
# 968  pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi
# 1012 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi
# 996  pop15 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi
# 978  pop15 pop75 dpi ddpi pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi
# 971  pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop75:dpi pop75:ddpi
# 983  pop15 pop75 dpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi
# 1017 pop15 pop75 dpi ddpi pop15:pop75 pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi
# 1020 pop15 pop75 ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi
# 1022 pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi
# 1016 pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop75:dpi pop75:ddpi dpi:ddpi
# 1019 pop15 pop75 dpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi
# 1015 pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi
# 1014 pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi
# 1018 pop15 pop75 dpi ddpi pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi
# 1021 pop15 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi
# 1013 pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi
# 1023 pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi
#      rsquare    adjr          predrsq     cp         aic      sbic     sbc
# 10   0.23376687  0.2178036766  0.16307339  4.8217409 283.5417 140.0370 289.2777
# 1    0.20751495  0.1910048430  0.14204347  6.5629449 285.2260 141.6036 290.9621
# 9    0.18774609  0.1708241315  0.09028334  7.8741488 286.4580 142.7507 292.1941
# 2    0.10018562  0.0814394890  0.02633607 13.6817485 291.5768 147.5295 297.3128
# 4    0.09289521  0.0739971952 -0.07790383 14.1652976 291.9802 147.9070 297.7163
# 3    0.04855805  0.0287363452 -0.03452048 17.1060366 294.3663 150.1423 300.1023
# 8    0.04752510  0.0276818722 -0.03588849 17.1745490 294.4205 150.1932 300.1566
# 5    0.03577439  0.0156863515 -0.05065374 17.9539355 295.0336 150.7683 300.7697
# 6    0.01973083 -0.0006914426 -0.06692714 19.0180519 295.8587 151.5428 301.5948
# 7    0.01434686 -0.0061875850 -0.09534970 19.3751535 296.1326 151.8000 301.8686
# 37   0.34772563  0.3199692784  0.26597790 -0.7367719 277.4906 134.1181 285.1387
# 49   0.33004132  0.3015324449  0.24137448  0.4361706 278.8281 135.3140 286.4762
# 34   0.31534712  0.2862129591  0.21499172  1.4107889 279.9129 136.2856 287.5610
# 54   0.30555168  0.2760006893  0.20386837  2.0604886 280.6232 136.9225 288.2713
# 13   0.28778797  0.2574810762  0.15196407  3.2386975 281.8861 138.0564 289.5342
# 40   0.26566894  0.2344208149  0.13963259  4.7057802 283.4153 139.4321 291.0634
# 16   0.26314138  0.2317856903  0.11419424  4.8734256 283.5871 139.5868 291.2352
# 11   0.26174551  0.2303304222  0.15529203  4.9660091 283.6818 139.6721 291.3299
# 14   0.26011869  0.2286343805  0.14786015  5.0739104 283.7918 139.7712 291.4399
# 17   0.25994297  0.2284511772  0.17563731  5.0855657 283.8037 139.7819 291.4518
# 55   0.25739186  0.2257915149  0.14453447  5.2547722 283.9758 139.9370 291.6239
# 18   0.25419652  0.2224602013  0.14739590  5.4667087 284.1904 140.1305 291.8385
# 19   0.24990703  0.2179881812  0.15673973  5.7512165 284.4772 140.3890 292.1253
# 45   0.24848438  0.2165049878  0.13360584  5.8455766 284.5719 140.4745 292.2200
# 52   0.24786172  0.2158558349  0.13685307  5.8868754 284.6134 140.5118 292.2614
# 12   0.24349092  0.2112990464  0.16421854  6.1767761 284.9031 140.7732 292.5512
# 15   0.24196382  0.2097069633  0.16116049  6.2780636 285.0039 140.8642 292.6520
# 27   0.23627605  0.2037771580  0.12630439  6.6553150 285.3777 141.2016 293.0258
# 51   0.21136222  0.1778031637  0.03279458  8.3077680 286.9827 142.6526 294.6308
# 33   0.19582014  0.1615997168  0.05482204  9.3386235 287.9585 143.5363 295.6066
# ...  ...        ...           ...         ...        ...      ...      ...
# 1009 0.4010075  0.2841309     0.13170978   7.729218  285.2298 140.3975 304.3500
# 986  0.4009954  0.2841165     0.16017780   7.730016  285.2308 140.3982 304.3510
# 1002 0.4009680  0.2840837     0.15392397   7.731835  285.2331 140.3998 304.3533
# 1006 0.4006549  0.2837095     0.08592993   7.752605  285.2592 140.4177 304.3795
# 988  0.4005634  0.2836001     0.16090200   7.758674  285.2669 140.4230 304.3871
# 970  0.3999159  0.2828263     0.16860965   7.801618  285.3208 140.4601 304.4411
# 997  0.3985473  0.2811906     0.16346400   7.892396  285.4347 140.5384 304.5550
# 991  0.3977334  0.2802180     0.12407696   7.946377  285.5024 140.5849 304.6226
# 974  0.3953208  0.2773346     0.10984668   8.106396  285.7022 140.7226 304.8225
# 1004 0.3949542  0.2768965     0.12928245   8.130709  285.7325 140.7435 304.8528
# 989  0.3943997  0.2762338     0.10787979   8.167488  285.7783 140.7751 304.8986
# 979  0.3934456  0.2750935     0.15342195   8.230774  285.8571 140.8294 304.9773
# 969  0.3915180  0.2727898     0.10613413   8.358622  286.0157 140.9390 305.1359
# 968  0.3891423  0.2699505     0.13762362   8.516199  286.2105 141.0737 305.3308
# 1012 0.3884243  0.2690924     0.11506005   8.563820  286.2693 141.1144 305.3895
# 996  0.3862343  0.2664751     0.11441070   8.709077  286.4480 141.2382 305.5682
# 978  0.3859008  0.2660766     0.10958434   8.731191  286.4752 141.2570 305.5954
# 971  0.3672293  0.2437618     0.08326090   9.969614  287.9727 142.3009 307.0930
# 983  0.3663144  0.2426685     0.09003700  10.030294  288.0450 142.3516 307.1652
# 1017 0.4120015  0.2797019     0.08964375   9.000018  286.3036 141.4740 307.3358
# 1020 0.4119873  0.2796845     0.08996525   9.000961  286.3048 141.4748 307.3370
# 1022 0.4115675  0.2791702     0.09666021   9.028803  286.3404 141.4980 307.3727
# 1016 0.4115027  0.2790908     0.12042670   9.033106  286.3460 141.5015 307.3782
# 1019 0.4101566  0.2774419     0.12998677   9.122383  286.4602 141.5756 307.4924
# 1015 0.4063733  0.2728073     0.06693774   9.373321  286.7799 141.7833 307.8121
# 1014 0.4053615  0.2715678     0.14000186   9.440431  286.8650 141.8388 307.8973
# 1018 0.4038624  0.2697314     0.09780568   9.539861  286.9909 141.9208 308.0232
# 1021 0.4021545  0.2676393     0.10209603   9.653136  287.1340 142.0141 308.1662
# 1013 0.3955032  0.2594914     0.07008761  10.094300  287.6872 142.3762 308.7194
# 1023 0.4120018  0.2612330     0.04321427  11.000000  288.3035 143.1846 311.2478
#      msep     fpe      apc       hsp
# 10   16.35665 16.32992 0.8300859 0.3340818
# 1    16.91704 16.88940 0.8585255 0.3455278
# 9    17.33904 17.31071 0.8799417 0.3541471
# 2    19.20818 19.17679 0.9747989 0.3923240
# 4    19.36381 19.33217 0.9826969 0.3955026
# 3    20.31027 20.27708 1.0307288 0.4148339
# 8    20.33232 20.29909 1.0318478 0.4152842
# 5    20.58316 20.54952 1.0445777 0.4204076
# 6    20.92564 20.89144 1.0619583 0.4274027
# 7    21.04057 21.00619 1.0677909 0.4297501
# 37   14.52938 14.47003 0.7355434 0.2967602
# 49   14.92330 14.86233 0.7554853 0.3048059
# 34   15.25061 15.18831 0.7720554 0.3114912
# 54   15.46880 15.40561 0.7831013 0.3159477
# 13   15.86449 15.79968 0.8031327 0.3240295
# 40   16.35719 16.29037 0.8280754 0.3340929
# 16   16.41349 16.34644 0.8309257 0.3352428
# 11   16.44458 16.37741 0.8324997 0.3358779
# 14   16.48082 16.41349 0.8343342 0.3366180
# 17   16.48473 16.41739 0.8345324 0.3366980
# 55   16.54156 16.47399 0.8374092 0.3378586
# 18   16.61273 16.54487 0.8410124 0.3393124
# 19   16.70828 16.64003 0.8458495 0.3412639
# 45   16.73997 16.67159 0.8474538 0.3419112
# 52   16.75384 16.68540 0.8481559 0.3421945
# 12   16.85120 16.78236 0.8530847 0.3441830
# 15   16.88522 16.81624 0.8548068 0.3448778
# 27   17.01191 16.94242 0.8612206 0.3474655
# 51   17.56687 17.49511 0.8893149 0.3588004
# 33   17.91307 17.83989 0.9068411 0.3658714
# ...  ...      ...      ...       ...
# 1009 17.58936 16.95706 0.8619649 0.3592597
# 986  17.58971 16.95740 0.8619822 0.3592670
# 1002 17.59052 16.95818 0.8620216 0.3592834
# 1006 17.59971 16.96704 0.8624723 0.3594712
# 988  17.60240 16.96963 0.8626039 0.3595261
# 970  17.62141 16.98796 0.8635357 0.3599144
# 997  17.66160 17.02671 0.8655052 0.3607353
# 991  17.68550 17.04975 0.8666763 0.3612234
# 974  17.75635 17.11805 0.8701481 0.3626704
# 1004 17.76711 17.12842 0.8706756 0.3628903
# 989  17.78339 17.14412 0.8714736 0.3632229
# 979  17.81141 17.17113 0.8728466 0.3637952
# 969  17.86801 17.22570 0.8756204 0.3649513
# 968  17.93778 17.29296 0.8790392 0.3663762
# 1012 17.95886 17.31328 0.8800724 0.3668068
# 996  18.02317 17.37528 0.8832239 0.3681203
# 978  18.03296 17.38472 0.8837037 0.3683203
# 971  18.58125 17.91330 0.9105725 0.3795190
# 983  18.60811 17.93920 0.9118890 0.3800677
# 1017 18.15198 17.35116 0.8819977 0.3707512
# 1020 18.15242 17.35158 0.8820190 0.3707602
# 1022 18.16538 17.36396 0.8826487 0.3710249
# 1016 18.16738 17.36588 0.8827460 0.3710658
# 1019 18.20893 17.40560 0.8847650 0.3719145
# 1015 18.32573 17.51724 0.8904401 0.3743000
# 1014 18.35696 17.54710 0.8919578 0.3749380
# 1018 18.40324 17.59133 0.8942064 0.3758832
# 1021 18.45596 17.64173 0.8967682 0.3769601
# 1013 18.66130 17.83800 0.9067452 0.3811539
# 1023 19.10734 18.09265 0.9196895 0.3902643

# %% [markdown]
# OH MY! We iterated through thousands of models! Let's check which of them are the best based on different criteria.

# %%
# xtable
all_possible_second_order_models = all_possible_second_order_models[ , c("n","predictors", "rsquare", "adjr", "aic", "sbic")]
print(xtable(all_possible_second_order_models))
# Out:
# % latex table generated in R 3.4.3 by xtable 1.8-2 package
# % Sun Apr 08 17:24:28 2018
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrlrrrr}
#   \hline
#  & n & predictors & rsquare & adjr & aic & sbic \\
#   \hline
# 10 &   1 & dpi:ddpi & 0.23 & 0.22 & 283.54 & 140.04 \\
#   1 &   1 & pop15 & 0.21 & 0.19 & 285.23 & 141.60 \\
#   9 &   1 & pop75:ddpi & 0.19 & 0.17 & 286.46 & 142.75 \\
#   2 &   1 & pop75 & 0.10 & 0.08 & 291.58 & 147.53 \\
#   4 &   1 & ddpi & 0.09 & 0.07 & 291.98 & 147.91 \\
#   3 &   1 & dpi & 0.05 & 0.03 & 294.37 & 150.14 \\
#   8 &   1 & pop75:dpi & 0.05 & 0.03 & 294.42 & 150.19 \\
#   5 &   1 & pop15:pop75 & 0.04 & 0.02 & 295.03 & 150.77 \\
#   6 &   1 & pop15:dpi & 0.02 & -0.00 & 295.86 & 151.54 \\
#   7 &   1 & pop15:ddpi & 0.01 & -0.01 & 296.13 & 151.80 \\
#   37 &   2 & ddpi pop15:ddpi & 0.35 & 0.32 & 277.49 & 134.12 \\
#   49 &   2 & pop15:dpi dpi:ddpi & 0.33 & 0.30 & 278.83 & 135.31 \\
#   34 &   2 & dpi dpi:ddpi & 0.32 & 0.29 & 279.91 & 136.29 \\
#   54 &   2 & pop75:dpi dpi:ddpi & 0.31 & 0.28 & 280.62 & 136.92 \\
#   13 &   2 & pop15 ddpi & 0.29 & 0.26 & 281.89 & 138.06 \\
#   40 &   2 & ddpi dpi:ddpi & 0.27 & 0.23 & 283.42 & 139.43 \\
#   16 &   2 & pop15 pop15:ddpi & 0.26 & 0.23 & 283.59 & 139.59 \\
#   11 &   2 & pop15 pop75 & 0.26 & 0.23 & 283.68 & 139.67 \\
#   14 &   2 & pop15 pop15:pop75 & 0.26 & 0.23 & 283.79 & 139.77 \\
#   17 &   2 & pop15 pop75:dpi & 0.26 & 0.23 & 283.80 & 139.78 \\
#   55 &   2 & pop75:ddpi dpi:ddpi & 0.26 & 0.23 & 283.98 & 139.94 \\
#   18 &   2 & pop15 pop75:ddpi & 0.25 & 0.22 & 284.19 & 140.13 \\
#   19 &   2 & pop15 dpi:ddpi & 0.25 & 0.22 & 284.48 & 140.39 \\
#   45 &   2 & pop15:pop75 dpi:ddpi & 0.25 & 0.22 & 284.57 & 140.47 \\
#   52 &   2 & pop15:ddpi dpi:ddpi & 0.25 & 0.22 & 284.61 & 140.51 \\
#   12 &   2 & pop15 dpi & 0.24 & 0.21 & 284.90 & 140.77 \\
#   15 &   2 & pop15 pop15:dpi & 0.24 & 0.21 & 285.00 & 140.86 \\
#   27 &   2 & pop75 dpi:ddpi & 0.24 & 0.20 & 285.38 & 141.20 \\
#   51 &   2 & pop15:ddpi pop75:ddpi & 0.21 & 0.18 & 286.98 & 142.65 \\
#   33 &   2 & dpi pop75:ddpi & 0.20 & 0.16 & 287.96 & 143.54 \\
#   44 &   2 & pop15:pop75 pop75:ddpi & 0.19 & 0.16 & 288.06 & 143.63 \\
#   26 &   2 & pop75 pop75:ddpi & 0.19 & 0.16 & 288.12 & 143.68 \\
#   53 &   2 & pop75:dpi pop75:ddpi & 0.19 & 0.16 & 288.23 & 143.78 \\
#   39 &   2 & ddpi pop75:ddpi & 0.19 & 0.16 & 288.29 & 143.84 \\
#   48 &   2 & pop15:dpi pop75:ddpi & 0.19 & 0.16 & 288.31 & 143.85 \\
#   21 &   2 & pop75 ddpi & 0.19 & 0.15 & 288.42 & 143.96 \\
#   22 &   2 & pop75 pop15:pop75 & 0.19 & 0.15 & 288.63 & 144.14 \\
#   28 &   2 & dpi ddpi & 0.16 & 0.13 & 290.04 & 145.43 \\
#   38 &   2 & ddpi pop75:dpi & 0.16 & 0.12 & 290.28 & 145.65 \\
#   24 &   2 & pop75 pop15:ddpi & 0.14 & 0.10 & 291.48 & 146.73 \\
#   36 &   2 & ddpi pop15:dpi & 0.13 & 0.09 & 291.83 & 147.05 \\
#   30 &   2 & dpi pop15:dpi & 0.13 & 0.09 & 291.83 & 147.06 \\
#   35 &   2 & ddpi pop15:pop75 & 0.12 & 0.08 & 292.35 & 147.53 \\
#   25 &   2 & pop75 pop75:dpi & 0.11 & 0.07 & 292.91 & 148.04 \\
#   23 &   2 & pop75 pop15:dpi & 0.11 & 0.07 & 293.01 & 148.13 \\
#   20 &   2 & pop75 dpi & 0.10 & 0.06 & 293.46 & 148.54 \\
#   31 &   2 & dpi pop15:ddpi & 0.09 & 0.05 & 294.25 & 149.26 \\
#   50 &   2 & pop15:ddpi pop75:dpi & 0.09 & 0.05 & 294.40 & 149.40 \\
#   47 &   2 & pop15:dpi pop75:dpi & 0.06 & 0.02 & 295.67 & 150.56 \\
#   42 &   2 & pop15:pop75 pop15:ddpi & 0.06 & 0.02 & 295.94 & 150.81 \\
#   29 &   2 & dpi pop15:pop75 & 0.05 & 0.01 & 296.23 & 151.07 \\
#   46 &   2 & pop15:dpi pop15:ddpi & 0.05 & 0.01 & 296.30 & 151.14 \\
#   43 &   2 & pop15:pop75 pop75:dpi & 0.05 & 0.01 & 296.34 & 151.18 \\
#   32 &   2 & dpi pop75:dpi & 0.05 & 0.01 & 296.35 & 151.18 \\
#   41 &   2 & pop15:pop75 pop15:dpi & 0.04 & -0.00 & 297.00 & 151.78 \\
#   90 &   3 & pop15 pop75:dpi dpi:ddpi & 0.38 & 0.34 & 276.73 & 133.29 \\
#   70 &   3 & pop15 dpi dpi:ddpi & 0.37 & 0.33 & 277.44 & 133.89 \\
#   151 &   3 & ddpi pop15:ddpi pop75:ddpi & 0.37 & 0.33 & 277.67 & 134.09 \\
#   142 &   3 & ddpi pop15:pop75 pop15:ddpi & 0.37 & 0.32 & 278.14 & 134.49 \\
#   85 &   3 & pop15 pop15:dpi dpi:ddpi & 0.36 & 0.32 & 278.58 & 134.88 \\
#   101 &   3 & pop75 ddpi pop15:ddpi & 0.35 & 0.31 & 279.02 & 135.26 \\
#   80 &   3 & pop15 pop15:pop75 pop75:ddpi & 0.35 & 0.31 & 279.24 & 135.44 \\
#   150 &   3 & ddpi pop15:ddpi pop75:dpi & 0.35 & 0.31 & 279.29 & 135.49 \\
#   146 &   3 & ddpi pop15:dpi pop15:ddpi & 0.35 & 0.31 & 279.29 & 135.49 \\
#   122 &   3 & dpi ddpi pop15:ddpi & 0.35 & 0.31 & 279.39 & 135.57 \\
#   73 &   3 & pop15 ddpi pop15:ddpi & 0.35 & 0.31 & 279.47 & 135.64 \\
#   152 &   3 & ddpi pop15:ddpi dpi:ddpi & 0.35 & 0.31 & 279.47 & 135.65 \\
#   71 &   3 & pop15 ddpi pop15:pop75 & 0.35 & 0.30 & 279.63 & 135.78 \\
#   62 &   3 & pop15 pop75 pop75:ddpi & 0.34 & 0.30 & 279.94 & 136.05 \\
#   118 &   3 & pop75 pop75:dpi dpi:ddpi & 0.34 & 0.30 & 280.11 & 136.20 \\
#   57 &   3 & pop15 pop75 ddpi & 0.34 & 0.29 & 280.34 & 136.39 \\
#   170 &   3 & pop15:dpi pop75:dpi dpi:ddpi & 0.33 & 0.29 & 280.62 & 136.64 \\
#   113 &   3 & pop75 pop15:dpi dpi:ddpi & 0.33 & 0.29 & 280.64 & 136.66 \\
#   168 &   3 & pop15:dpi pop15:ddpi dpi:ddpi & 0.33 & 0.29 & 280.76 & 136.76 \\
#   134 &   3 & dpi pop15:dpi dpi:ddpi & 0.33 & 0.29 & 280.81 & 136.80 \\
#   171 &   3 & pop15:dpi pop75:ddpi dpi:ddpi & 0.33 & 0.29 & 280.82 & 136.81 \\
#   159 &   3 & pop15:pop75 pop15:dpi dpi:ddpi & 0.33 & 0.29 & 280.83 & 136.81 \\
#   149 &   3 & ddpi pop15:dpi dpi:ddpi & 0.33 & 0.29 & 280.83 & 136.81 \\
#   98 &   3 & pop75 dpi dpi:ddpi & 0.33 & 0.28 & 281.09 & 137.04 \\
#   78 &   3 & pop15 pop15:pop75 pop15:ddpi & 0.33 & 0.28 & 281.14 & 137.09 \\
#   60 &   3 & pop15 pop75 pop15:ddpi & 0.32 & 0.27 & 281.71 & 137.58 \\
#   137 &   3 & dpi pop15:ddpi dpi:ddpi & 0.32 & 0.27 & 281.80 & 137.66 \\
#   139 &   3 & dpi pop75:dpi dpi:ddpi & 0.32 & 0.27 & 281.89 & 137.74 \\
#   140 &   3 & dpi pop75:ddpi dpi:ddpi & 0.32 & 0.27 & 281.89 & 137.74 \\
#   130 &   3 & dpi pop15:pop75 dpi:ddpi & 0.32 & 0.27 & 281.91 & 137.75 \\
#   125 &   3 & dpi ddpi dpi:ddpi & 0.32 & 0.27 & 281.91 & 137.75 \\
#   74 &   3 & pop15 ddpi pop75:dpi & 0.31 & 0.27 & 281.95 & 137.79 \\
#   63 &   3 & pop15 pop75 dpi:ddpi & 0.31 & 0.27 & 282.14 & 137.96 \\
#   175 &   3 & pop75:dpi pop75:ddpi dpi:ddpi & 0.31 & 0.27 & 282.24 & 138.04 \\
#   164 &   3 & pop15:pop75 pop75:dpi dpi:ddpi & 0.31 & 0.26 & 282.51 & 138.28 \\
#   154 &   3 & ddpi pop75:dpi dpi:ddpi & 0.31 & 0.26 & 282.54 & 138.30 \\
#   173 &   3 & pop15:ddpi pop75:dpi dpi:ddpi & 0.31 & 0.26 & 282.61 & 138.36 \\
#   81 &   3 & pop15 pop15:pop75 dpi:ddpi & 0.31 & 0.26 & 282.65 & 138.39 \\
#   64 &   3 & pop15 dpi ddpi & 0.30 & 0.26 & 282.83 & 138.55 \\
#   108 &   3 & pop75 pop15:pop75 pop75:ddpi & 0.30 & 0.26 & 282.87 & 138.59 \\
#   72 &   3 & pop15 ddpi pop15:dpi & 0.30 & 0.26 & 282.92 & 138.63 \\
#   76 &   3 & pop15 ddpi dpi:ddpi & 0.30 & 0.25 & 283.08 & 138.77 \\
#   86 &   3 & pop15 pop15:ddpi pop75:dpi & 0.30 & 0.25 & 283.12 & 138.80 \\
#   75 &   3 & pop15 ddpi pop75:ddpi & 0.30 & 0.25 & 283.21 & 138.88 \\
#   89 &   3 & pop15 pop75:dpi pop75:ddpi & 0.30 & 0.25 & 283.36 & 139.01 \\
#   99 &   3 & pop75 ddpi pop15:pop75 & 0.29 & 0.25 & 283.45 & 139.09 \\
#   165 &   3 & pop15:pop75 pop75:ddpi dpi:ddpi & 0.29 & 0.24 & 283.71 & 139.32 \\
#   67 &   3 & pop15 dpi pop15:ddpi & 0.28 & 0.24 & 284.16 & 139.71 \\
#   79 &   3 & pop15 pop15:pop75 pop75:dpi & 0.28 & 0.24 & 284.23 & 139.77 \\
#   88 &   3 & pop15 pop15:ddpi dpi:ddpi & 0.28 & 0.24 & 284.24 & 139.78 \\
#   82 &   3 & pop15 pop15:dpi pop15:ddpi & 0.28 & 0.24 & 284.30 & 139.83 \\
#   161 &   3 & pop15:pop75 pop15:ddpi pop75:ddpi & 0.28 & 0.23 & 284.61 & 140.10 \\
#   65 &   3 & pop15 dpi pop15:pop75 & 0.28 & 0.23 & 284.65 & 140.13 \\
#   69 &   3 & pop15 dpi pop75:ddpi & 0.28 & 0.23 & 284.68 & 140.16 \\
#   145 &   3 & ddpi pop15:pop75 dpi:ddpi & 0.28 & 0.23 & 284.74 & 140.22 \\
#   61 &   3 & pop15 pop75 pop75:dpi & 0.28 & 0.23 & 284.75 & 140.22 \\
#   59 &   3 & pop15 pop75 pop15:dpi & 0.27 & 0.23 & 284.78 & 140.25 \\
#   84 &   3 & pop15 pop15:dpi pop75:ddpi & 0.27 & 0.23 & 284.79 & 140.26 \\
#   56 &   3 & pop15 pop75 dpi & 0.27 & 0.23 & 284.82 & 140.28 \\
#   77 &   3 & pop15 pop15:pop75 pop15:dpi & 0.27 & 0.23 & 284.87 & 140.33 \\
#   91 &   3 & pop15 pop75:ddpi dpi:ddpi & 0.27 & 0.22 & 285.12 & 140.54 \\
#   109 &   3 & pop75 pop15:pop75 dpi:ddpi & 0.27 & 0.22 & 285.24 & 140.65 \\
#   155 &   3 & ddpi pop75:ddpi dpi:ddpi & 0.27 & 0.22 & 285.41 & 140.79 \\
#   104 &   3 & pop75 ddpi dpi:ddpi & 0.27 & 0.22 & 285.41 & 140.80 \\
#   119 &   3 & pop75 pop75:ddpi dpi:ddpi & 0.26 & 0.22 & 285.47 & 140.85 \\
#   87 &   3 & pop15 pop15:ddpi pop75:ddpi & 0.26 & 0.22 & 285.56 & 140.92 \\
#   58 &   3 & pop15 pop75 pop15:pop75 & 0.26 & 0.22 & 285.56 & 140.93 \\
#   68 &   3 & pop15 dpi pop75:dpi & 0.26 & 0.22 & 285.58 & 140.95 \\
#   83 &   3 & pop15 pop15:dpi pop75:dpi & 0.26 & 0.21 & 285.80 & 141.14 \\
#   162 &   3 & pop15:pop75 pop15:ddpi dpi:ddpi & 0.26 & 0.21 & 285.89 & 141.22 \\
#   174 &   3 & pop15:ddpi pop75:ddpi dpi:ddpi & 0.26 & 0.21 & 285.97 & 141.29 \\
#   106 &   3 & pop75 pop15:pop75 pop15:ddpi & 0.25 & 0.20 & 286.29 & 141.57 \\
#   116 &   3 & pop75 pop15:ddpi dpi:ddpi & 0.25 & 0.20 & 286.60 & 141.84 \\
#   66 &   3 & pop15 dpi pop15:dpi & 0.24 & 0.19 & 286.90 & 142.10 \\
#   129 &   3 & dpi pop15:pop75 pop75:ddpi & 0.23 & 0.18 & 287.76 & 142.85 \\
#   144 &   3 & ddpi pop15:pop75 pop75:ddpi & 0.23 & 0.18 & 287.93 & 143.01 \\
#   107 &   3 & pop75 pop15:pop75 pop75:dpi & 0.23 & 0.18 & 288.04 & 143.10 \\
#   163 &   3 & pop15:pop75 pop75:dpi pop75:ddpi & 0.22 & 0.17 & 288.29 & 143.32 \\
#   115 &   3 & pop75 pop15:ddpi pop75:ddpi & 0.22 & 0.17 & 288.38 & 143.40 \\
#   133 &   3 & dpi pop15:dpi pop75:ddpi & 0.22 & 0.17 & 288.40 & 143.42 \\
#   172 &   3 & pop15:ddpi pop75:dpi pop75:ddpi & 0.21 & 0.16 & 288.78 & 143.75 \\
#   121 &   3 & dpi ddpi pop15:dpi & 0.21 & 0.16 & 288.79 & 143.76 \\
#   167 &   3 & pop15:dpi pop15:ddpi pop75:ddpi & 0.21 & 0.16 & 288.88 & 143.83 \\
#   158 &   3 & pop15:pop75 pop15:dpi pop75:ddpi & 0.21 & 0.16 & 288.92 & 143.88 \\
#   136 &   3 & dpi pop15:ddpi pop75:ddpi & 0.21 & 0.16 & 288.98 & 143.92 \\
#   138 &   3 & dpi pop75:dpi pop75:ddpi & 0.21 & 0.15 & 289.32 & 144.23 \\
#   132 &   3 & dpi pop15:dpi pop75:dpi & 0.20 & 0.15 & 289.72 & 144.58 \\
#   93 &   3 & pop75 dpi pop15:pop75 & 0.20 & 0.14 & 289.96 & 144.79 \\
#   97 &   3 & pop75 dpi pop75:ddpi & 0.20 & 0.14 & 289.96 & 144.79 \\
#   124 &   3 & dpi ddpi pop75:ddpi & 0.20 & 0.14 & 289.96 & 144.79 \\
#   103 &   3 & pop75 ddpi pop75:ddpi & 0.19 & 0.14 & 290.08 & 144.90 \\
#   117 &   3 & pop75 pop75:dpi pop75:ddpi & 0.19 & 0.14 & 290.12 & 144.93 \\
#   112 &   3 & pop75 pop15:dpi pop75:ddpi & 0.19 & 0.14 & 290.12 & 144.93 \\
#   105 &   3 & pop75 pop15:pop75 pop15:dpi & 0.19 & 0.14 & 290.13 & 144.94 \\
#   153 &   3 & ddpi pop75:dpi pop75:ddpi & 0.19 & 0.14 & 290.22 & 145.01 \\
#   169 &   3 & pop15:dpi pop75:dpi pop75:ddpi & 0.19 & 0.14 & 290.22 & 145.02 \\
#   148 &   3 & ddpi pop15:dpi pop75:ddpi & 0.19 & 0.14 & 290.25 & 145.05 \\
#   102 &   3 & pop75 ddpi pop75:dpi & 0.19 & 0.14 & 290.36 & 145.14 \\
#   92 &   3 & pop75 dpi ddpi & 0.19 & 0.14 & 290.38 & 145.16 \\
#   100 &   3 & pop75 ddpi pop15:dpi & 0.19 & 0.14 & 290.38 & 145.16 \\
#   131 &   3 & dpi pop15:dpi pop15:ddpi & 0.16 & 0.11 & 291.89 & 146.49 \\
#   147 &   3 & ddpi pop15:dpi pop75:dpi & 0.16 & 0.11 & 292.00 & 146.59 \\
#   120 &   3 & dpi ddpi pop15:pop75 & 0.16 & 0.11 & 292.02 & 146.61 \\
#   123 &   3 & dpi ddpi pop75:dpi & 0.16 & 0.11 & 292.04 & 146.63 \\
#   143 &   3 & ddpi pop15:pop75 pop75:dpi & 0.16 & 0.10 & 292.20 & 146.77 \\
#   114 &   3 & pop75 pop15:ddpi pop75:dpi & 0.14 & 0.09 & 293.22 & 147.67 \\
#   110 &   3 & pop75 pop15:dpi pop15:ddpi & 0.14 & 0.08 & 293.30 & 147.74 \\
#   94 &   3 & pop75 dpi pop15:dpi & 0.14 & 0.08 & 293.35 & 147.79 \\
#   95 &   3 & pop75 dpi pop15:ddpi & 0.14 & 0.08 & 293.48 & 147.90 \\
#   141 &   3 & ddpi pop15:pop75 pop15:dpi & 0.13 & 0.08 & 293.66 & 148.06 \\
#   96 &   3 & pop75 dpi pop75:dpi & 0.13 & 0.08 & 293.68 & 148.08 \\
#   126 &   3 & dpi pop15:pop75 pop15:dpi & 0.13 & 0.07 & 293.83 & 148.21 \\
#   111 &   3 & pop75 pop15:dpi pop75:dpi & 0.11 & 0.05 & 294.89 & 149.15 \\
#   166 &   3 & pop15:dpi pop15:ddpi pop75:dpi & 0.09 & 0.04 & 295.88 & 150.03 \\
#   127 &   3 & dpi pop15:pop75 pop15:ddpi & 0.09 & 0.03 & 296.21 & 150.33 \\
#   135 &   3 & dpi pop15:ddpi pop75:dpi & 0.09 & 0.03 & 296.23 & 150.35 \\
#   160 &   3 & pop15:pop75 pop15:ddpi pop75:dpi & 0.09 & 0.03 & 296.40 & 150.50 \\
#   157 &   3 & pop15:pop75 pop15:dpi pop75:dpi & 0.06 & 0.00 & 297.63 & 151.60 \\
#   156 &   3 & pop15:pop75 pop15:dpi pop15:ddpi & 0.06 & 0.00 & 297.65 & 151.62 \\
#   128 &   3 & dpi pop15:pop75 pop75:dpi & 0.05 & -0.01 & 298.23 & 152.13 \\
#   304 &   4 & pop75 pop15:pop75 pop75:dpi dpi:ddpi & 0.39 & 0.34 & 277.82 & 134.17 \\
#   214 &   4 & pop15 dpi pop15:pop75 dpi:ddpi & 0.39 & 0.34 & 278.09 & 134.38 \\
#   248 &   4 & pop15 pop15:pop75 pop75:dpi dpi:ddpi & 0.39 & 0.34 & 278.12 & 134.41 \\
#   182 &   4 & pop15 pop75 dpi dpi:ddpi & 0.39 & 0.34 & 278.20 & 134.48 \\
#   254 &   4 & pop15 pop15:dpi pop75:dpi dpi:ddpi & 0.39 & 0.33 & 278.28 & 134.54 \\
#   223 &   4 & pop15 dpi pop75:dpi dpi:ddpi & 0.39 & 0.33 & 278.50 & 134.72 \\
#   257 &   4 & pop15 pop15:ddpi pop75:dpi dpi:ddpi & 0.38 & 0.33 & 278.58 & 134.79 \\
#   238 &   4 & pop15 ddpi pop75:dpi dpi:ddpi & 0.38 & 0.33 & 278.59 & 134.80 \\
#   202 &   4 & pop15 pop75 pop75:dpi dpi:ddpi & 0.38 & 0.33 & 278.63 & 134.83 \\
#   259 &   4 & pop15 pop75:dpi pop75:ddpi dpi:ddpi & 0.38 & 0.33 & 278.73 & 134.91 \\
#   226 &   4 & pop15 ddpi pop15:pop75 pop15:ddpi & 0.38 & 0.33 & 278.79 & 134.97 \\
#   235 &   4 & pop15 ddpi pop15:ddpi pop75:ddpi & 0.38 & 0.33 & 278.89 & 135.04 \\
#   197 &   4 & pop15 pop75 pop15:dpi dpi:ddpi & 0.38 & 0.33 & 278.89 & 135.05 \\
#   224 &   4 & pop15 dpi pop75:ddpi dpi:ddpi & 0.38 & 0.32 & 279.08 & 135.20 \\
#   282 &   4 & pop75 ddpi pop15:pop75 pop15:ddpi & 0.38 & 0.32 & 279.10 & 135.22 \\
#   291 &   4 & pop75 ddpi pop15:ddpi pop75:ddpi & 0.38 & 0.32 & 279.16 & 135.27 \\
#   218 &   4 & pop15 dpi pop15:dpi dpi:ddpi & 0.37 & 0.32 & 279.40 & 135.46 \\
#   209 &   4 & pop15 dpi ddpi dpi:ddpi & 0.37 & 0.32 & 279.40 & 135.46 \\
#   221 &   4 & pop15 dpi pop15:ddpi dpi:ddpi & 0.37 & 0.32 & 279.40 & 135.47 \\
#   243 &   4 & pop15 pop15:pop75 pop15:dpi dpi:ddpi & 0.37 & 0.32 & 279.40 & 135.47 \\
#   369 &   4 & ddpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.37 & 0.32 & 279.43 & 135.49 \\
#   367 &   4 & ddpi pop15:ddpi pop75:dpi pop75:ddpi & 0.37 & 0.32 & 279.53 & 135.57 \\
#   185 &   4 & pop15 pop75 ddpi pop15:ddpi & 0.37 & 0.32 & 279.53 & 135.58 \\
#   326 &   4 & dpi ddpi pop15:ddpi pop75:ddpi & 0.37 & 0.32 & 279.61 & 135.64 \\
#   356 &   4 & ddpi pop15:pop75 pop15:ddpi pop75:ddpi & 0.37 & 0.32 & 279.66 & 135.69 \\
#   362 &   4 & ddpi pop15:dpi pop15:ddpi pop75:ddpi & 0.37 & 0.32 & 279.67 & 135.69 \\
#   357 &   4 & ddpi pop15:pop75 pop15:ddpi dpi:ddpi & 0.37 & 0.31 & 279.86 & 135.85 \\
#   355 &   4 & ddpi pop15:pop75 pop15:ddpi pop75:dpi & 0.37 & 0.31 & 279.96 & 135.94 \\
#   317 &   4 & dpi ddpi pop15:pop75 pop15:ddpi & 0.37 & 0.31 & 279.97 & 135.94 \\
#   351 &   4 & ddpi pop15:pop75 pop15:dpi pop15:ddpi & 0.37 & 0.31 & 280.09 & 136.04 \\
#   233 &   4 & pop15 ddpi pop15:dpi dpi:ddpi & 0.36 & 0.30 & 280.41 & 136.31 \\
#   363 &   4 & ddpi pop15:dpi pop15:ddpi dpi:ddpi & 0.36 & 0.30 & 280.43 & 136.33 \\
#   255 &   4 & pop15 pop15:dpi pop75:ddpi dpi:ddpi & 0.36 & 0.30 & 280.44 & 136.33 \\
#   252 &   4 & pop15 pop15:dpi pop15:ddpi dpi:ddpi & 0.36 & 0.30 & 280.48 & 136.36 \\
#   270 &   4 & pop75 dpi pop15:pop75 dpi:ddpi & 0.36 & 0.30 & 280.59 & 136.45 \\
#   368 &   4 & ddpi pop15:ddpi pop75:dpi dpi:ddpi & 0.36 & 0.30 & 280.59 & 136.45 \\
#   249 &   4 & pop15 pop15:pop75 pop75:ddpi dpi:ddpi & 0.36 & 0.30 & 280.63 & 136.49 \\
#   229 &   4 & pop15 ddpi pop15:pop75 dpi:ddpi & 0.36 & 0.30 & 280.70 & 136.54 \\
#   327 &   4 & dpi ddpi pop15:ddpi dpi:ddpi & 0.36 & 0.30 & 280.73 & 136.57 \\
#   292 &   4 & pop75 ddpi pop15:ddpi dpi:ddpi & 0.36 & 0.30 & 280.82 & 136.65 \\
#   234 &   4 & pop15 ddpi pop15:ddpi pop75:dpi & 0.36 & 0.30 & 280.86 & 136.68 \\
#   247 &   4 & pop15 pop15:pop75 pop75:dpi pop75:ddpi & 0.36 & 0.30 & 280.90 & 136.71 \\
#   203 &   4 & pop15 pop75 pop75:ddpi dpi:ddpi & 0.36 & 0.30 & 280.91 & 136.72 \\
#   345 &   4 & dpi pop15:dpi pop75:dpi dpi:ddpi & 0.35 & 0.30 & 280.97 & 136.77 \\
#   262 &   4 & pop75 dpi ddpi pop15:ddpi & 0.35 & 0.30 & 280.99 & 136.79 \\
#   290 &   4 & pop75 ddpi pop15:ddpi pop75:dpi & 0.35 & 0.30 & 281.00 & 136.79 \\
#   286 &   4 & pop75 ddpi pop15:dpi pop15:ddpi & 0.35 & 0.30 & 281.02 & 136.81 \\
#   188 &   4 & pop15 pop75 ddpi dpi:ddpi & 0.35 & 0.30 & 281.06 & 136.84 \\
#   230 &   4 & pop15 ddpi pop15:dpi pop15:ddpi & 0.35 & 0.30 & 281.10 & 136.88 \\
#   321 &   4 & dpi ddpi pop15:dpi pop15:ddpi & 0.35 & 0.29 & 281.13 & 136.91 \\
#   192 &   4 & pop15 pop75 pop15:pop75 pop75:ddpi & 0.35 & 0.29 & 281.14 & 136.91 \\
#   213 &   4 & pop15 dpi pop15:pop75 pop75:ddpi & 0.35 & 0.29 & 281.14 & 136.91 \\
#   206 &   4 & pop15 dpi ddpi pop15:ddpi & 0.35 & 0.29 & 281.17 & 136.94 \\
#   245 &   4 & pop15 pop15:pop75 pop15:ddpi pop75:ddpi & 0.35 & 0.29 & 281.18 & 136.95 \\
#   228 &   4 & pop15 ddpi pop15:pop75 pop75:ddpi & 0.35 & 0.29 & 281.18 & 136.95 \\
#   325 &   4 & dpi ddpi pop15:ddpi pop75:dpi & 0.35 & 0.29 & 281.19 & 136.95 \\
#   242 &   4 & pop15 pop15:pop75 pop15:dpi pop75:ddpi & 0.35 & 0.29 & 281.23 & 136.98 \\
#   227 &   4 & pop15 ddpi pop15:pop75 pop75:dpi & 0.35 & 0.29 & 281.25 & 137.01 \\
#   361 &   4 & ddpi pop15:dpi pop15:ddpi pop75:dpi & 0.35 & 0.29 & 281.28 & 137.03 \\
#   310 &   4 & pop75 pop15:dpi pop75:dpi dpi:ddpi & 0.35 & 0.29 & 281.41 & 137.14 \\
#   204 &   4 & pop15 dpi ddpi pop15:pop75 & 0.35 & 0.29 & 281.44 & 137.16 \\
#   236 &   4 & pop15 ddpi pop15:ddpi dpi:ddpi & 0.35 & 0.29 & 281.46 & 137.18 \\
#   225 &   4 & pop15 ddpi pop15:pop75 pop15:dpi & 0.35 & 0.29 & 281.55 & 137.25 \\
#   183 &   4 & pop15 pop75 ddpi pop15:pop75 & 0.35 & 0.29 & 281.63 & 137.32 \\
#   246 &   4 & pop15 pop15:pop75 pop15:ddpi dpi:ddpi & 0.35 & 0.29 & 281.66 & 137.34 \\
#   299 &   4 & pop75 pop15:pop75 pop15:dpi dpi:ddpi & 0.34 & 0.29 & 281.73 & 137.40 \\
#   200 &   4 & pop15 pop75 pop15:ddpi dpi:ddpi & 0.34 & 0.29 & 281.82 & 137.47 \\
#   199 &   4 & pop15 pop75 pop15:ddpi pop75:ddpi & 0.34 & 0.28 & 281.84 & 137.49 \\
#   315 &   4 & pop75 pop75:dpi pop75:ddpi dpi:ddpi & 0.34 & 0.28 & 281.85 & 137.50 \\
#   196 &   4 & pop15 pop75 pop15:dpi pop75:ddpi & 0.34 & 0.28 & 281.90 & 137.54 \\
#   181 &   4 & pop15 pop75 dpi pop75:ddpi & 0.34 & 0.28 & 281.91 & 137.55 \\
#   201 &   4 & pop15 pop75 pop75:dpi pop75:ddpi & 0.34 & 0.28 & 281.91 & 137.55 \\
#   187 &   4 & pop15 pop75 ddpi pop75:ddpi & 0.34 & 0.28 & 281.93 & 137.56 \\
#   313 &   4 & pop75 pop15:ddpi pop75:dpi dpi:ddpi & 0.34 & 0.28 & 282.07 & 137.69 \\
#   279 &   4 & pop75 dpi pop75:dpi dpi:ddpi & 0.34 & 0.28 & 282.08 & 137.69 \\
#   294 &   4 & pop75 ddpi pop75:dpi dpi:ddpi & 0.34 & 0.28 & 282.11 & 137.72 \\
#   184 &   4 & pop15 pop75 ddpi pop15:dpi & 0.34 & 0.28 & 282.18 & 137.78 \\
#   186 &   4 & pop15 pop75 ddpi pop75:dpi & 0.34 & 0.28 & 282.19 & 137.79 \\
#   176 &   4 & pop15 pop75 dpi ddpi & 0.34 & 0.28 & 282.20 & 137.79 \\
#   382 &   4 & pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.33 & 0.28 & 282.48 & 138.03 \\
#   244 &   4 & pop15 pop15:pop75 pop15:ddpi pop75:dpi & 0.33 & 0.28 & 282.52 & 138.06 \\
#   311 &   4 & pop75 pop15:dpi pop75:ddpi dpi:ddpi & 0.33 & 0.27 & 282.55 & 138.09 \\
#   375 &   4 & pop15:pop75 pop15:dpi pop75:dpi dpi:ddpi & 0.33 & 0.27 & 282.58 & 138.11 \\
#   365 &   4 & ddpi pop15:dpi pop75:dpi dpi:ddpi & 0.33 & 0.27 & 282.61 & 138.14 \\
#   274 &   4 & pop75 dpi pop15:dpi dpi:ddpi & 0.33 & 0.27 & 282.61 & 138.14 \\
#   308 &   4 & pop75 pop15:dpi pop15:ddpi dpi:ddpi & 0.33 & 0.27 & 282.62 & 138.14 \\
#   384 &   4 & pop15:dpi pop75:dpi pop75:ddpi dpi:ddpi & 0.33 & 0.27 & 282.62 & 138.14 \\
#   289 &   4 & pop75 ddpi pop15:dpi dpi:ddpi & 0.33 & 0.27 & 282.64 & 138.16 \\
#   383 &   4 & pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.33 & 0.27 & 282.74 & 138.25 \\
#   343 &   4 & dpi pop15:dpi pop15:ddpi dpi:ddpi & 0.33 & 0.27 & 282.76 & 138.26 \\
#   373 &   4 & pop15:pop75 pop15:dpi pop15:ddpi dpi:ddpi & 0.33 & 0.27 & 282.76 & 138.26 \\
#   211 &   4 & pop15 dpi pop15:pop75 pop15:ddpi & 0.33 & 0.27 & 282.79 & 138.28 \\
#   334 &   4 & dpi pop15:pop75 pop15:dpi dpi:ddpi & 0.33 & 0.27 & 282.81 & 138.30 \\
#   324 &   4 & dpi ddpi pop15:dpi dpi:ddpi & 0.33 & 0.27 & 282.81 & 138.30 \\
#   346 &   4 & dpi pop15:dpi pop75:ddpi dpi:ddpi & 0.33 & 0.27 & 282.81 & 138.30 \\
#   366 &   4 & ddpi pop15:dpi pop75:ddpi dpi:ddpi & 0.33 & 0.27 & 282.81 & 138.30 \\
#   280 &   4 & pop75 dpi pop75:ddpi dpi:ddpi & 0.33 & 0.27 & 282.82 & 138.31 \\
#   376 &   4 & pop15:pop75 pop15:dpi pop75:ddpi dpi:ddpi & 0.33 & 0.27 & 282.82 & 138.31 \\
#   354 &   4 & ddpi pop15:pop75 pop15:dpi dpi:ddpi & 0.33 & 0.27 & 282.83 & 138.31 \\
#   240 &   4 & pop15 pop15:pop75 pop15:dpi pop15:ddpi & 0.33 & 0.27 & 282.96 & 138.43 \\
#   277 &   4 & pop75 dpi pop15:ddpi dpi:ddpi & 0.33 & 0.27 & 283.02 & 138.48 \\
#   265 &   4 & pop75 dpi ddpi dpi:ddpi & 0.33 & 0.27 & 283.09 & 138.54 \\
#   190 &   4 & pop15 pop75 pop15:pop75 pop15:ddpi & 0.33 & 0.27 & 283.12 & 138.56 \\
#   305 &   4 & pop75 pop15:pop75 pop75:ddpi dpi:ddpi & 0.32 & 0.26 & 283.40 & 138.80 \\
#   198 &   4 & pop15 pop75 pop15:ddpi pop75:dpi & 0.32 & 0.26 & 283.41 & 138.81 \\
#   194 &   4 & pop15 pop75 pop15:dpi pop15:ddpi & 0.32 & 0.26 & 283.44 & 138.83 \\
#   179 &   4 & pop15 pop75 dpi pop15:ddpi & 0.32 & 0.26 & 283.44 & 138.83 \\
#   385 &   4 & pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.32 & 0.26 & 283.54 & 138.91 \\
#   207 &   4 & pop15 dpi ddpi pop75:dpi & 0.32 & 0.26 & 283.55 & 138.92 \\
#   349 &   4 & dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.32 & 0.26 & 283.56 & 138.93 \\
#   285 &   4 & pop75 ddpi pop15:pop75 dpi:ddpi & 0.32 & 0.26 & 283.59 & 138.96 \\
#   237 &   4 & pop15 ddpi pop75:dpi pop75:ddpi & 0.32 & 0.26 & 283.67 & 139.02 \\
#   348 &   4 & dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.32 & 0.26 & 283.78 & 139.11 \\
#   337 &   4 & dpi pop15:pop75 pop15:ddpi dpi:ddpi & 0.32 & 0.26 & 283.79 & 139.12 \\
#   350 &   4 & dpi pop75:dpi pop75:ddpi dpi:ddpi & 0.32 & 0.26 & 283.85 & 139.17 \\
#   339 &   4 & dpi pop15:pop75 pop75:dpi dpi:ddpi & 0.32 & 0.26 & 283.87 & 139.19 \\
#   330 &   4 & dpi ddpi pop75:ddpi dpi:ddpi & 0.32 & 0.26 & 283.87 & 139.19 \\
#   231 &   4 & pop15 ddpi pop15:dpi pop75:dpi & 0.32 & 0.25 & 283.88 & 139.20 \\
#   340 &   4 & dpi pop15:pop75 pop75:ddpi dpi:ddpi & 0.32 & 0.25 & 283.89 & 139.20 \\
#   329 &   4 & dpi ddpi pop75:dpi dpi:ddpi & 0.32 & 0.25 & 283.89 & 139.20 \\
#   320 &   4 & dpi ddpi pop15:pop75 dpi:ddpi & 0.32 & 0.25 & 283.91 & 139.22 \\
#   239 &   4 & pop15 ddpi pop75:ddpi dpi:ddpi & 0.31 & 0.25 & 283.98 & 139.28 \\
#   370 &   4 & ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.31 & 0.25 & 284.08 & 139.37 \\
#   193 &   4 & pop15 pop75 pop15:pop75 dpi:ddpi & 0.31 & 0.25 & 284.11 & 139.39 \\
#   303 &   4 & pop75 pop15:pop75 pop75:dpi pop75:ddpi & 0.31 & 0.25 & 284.19 & 139.46 \\
#   379 &   4 & pop15:pop75 pop15:ddpi pop75:ddpi dpi:ddpi & 0.31 & 0.25 & 284.19 & 139.46 \\
#   380 &   4 & pop15:pop75 pop75:dpi pop75:ddpi dpi:ddpi & 0.31 & 0.25 & 284.23 & 139.49 \\
#   208 &   4 & pop15 dpi ddpi pop75:ddpi & 0.31 & 0.25 & 284.25 & 139.51 \\
#   301 &   4 & pop75 pop15:pop75 pop15:ddpi pop75:ddpi & 0.31 & 0.25 & 284.26 & 139.51 \\
#   232 &   4 & pop15 ddpi pop15:dpi pop75:ddpi & 0.31 & 0.25 & 284.33 & 139.57 \\
#   283 &   4 & pop75 ddpi pop15:pop75 pop75:dpi & 0.31 & 0.25 & 284.34 & 139.58 \\
#   359 &   4 & ddpi pop15:pop75 pop75:dpi dpi:ddpi & 0.31 & 0.25 & 284.47 & 139.69 \\
#   378 &   4 & pop15:pop75 pop15:ddpi pop75:dpi dpi:ddpi & 0.31 & 0.25 & 284.48 & 139.70 \\
#   222 &   4 & pop15 dpi pop75:dpi pop75:ddpi & 0.31 & 0.24 & 284.64 & 139.83 \\
#   219 &   4 & pop15 dpi pop15:ddpi pop75:dpi & 0.30 & 0.24 & 284.71 & 139.89 \\
#   205 &   4 & pop15 dpi ddpi pop15:dpi & 0.30 & 0.24 & 284.83 & 139.99 \\
#   298 &   4 & pop75 pop15:pop75 pop15:dpi pop75:ddpi & 0.30 & 0.24 & 284.84 & 140.00 \\
#   284 &   4 & pop75 ddpi pop15:pop75 pop75:ddpi & 0.30 & 0.24 & 284.85 & 140.01 \\
#   269 &   4 & pop75 dpi pop15:pop75 pop75:ddpi & 0.30 & 0.24 & 284.87 & 140.03 \\
#   256 &   4 & pop15 pop15:ddpi pop75:dpi pop75:ddpi & 0.30 & 0.24 & 285.04 & 140.17 \\
#   250 &   4 & pop15 pop15:dpi pop15:ddpi pop75:dpi & 0.30 & 0.24 & 285.05 & 140.18 \\
#   344 &   4 & dpi pop15:dpi pop75:dpi pop75:ddpi & 0.30 & 0.24 & 285.12 & 140.24 \\
#   302 &   4 & pop75 pop15:pop75 pop15:ddpi dpi:ddpi & 0.30 & 0.24 & 285.13 & 140.24 \\
#   253 &   4 & pop15 pop15:dpi pop75:dpi pop75:ddpi & 0.30 & 0.23 & 285.23 & 140.33 \\
#   260 &   4 & pop75 dpi ddpi pop15:pop75 & 0.29 & 0.23 & 285.38 & 140.46 \\
#   360 &   4 & ddpi pop15:pop75 pop75:ddpi dpi:ddpi & 0.29 & 0.23 & 285.41 & 140.48 \\
#   281 &   4 & pop75 ddpi pop15:pop75 pop15:dpi & 0.29 & 0.23 & 285.44 & 140.51 \\
#   336 &   4 & dpi pop15:pop75 pop15:ddpi pop75:ddpi & 0.29 & 0.23 & 285.85 & 140.85 \\
#   372 &   4 & pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi & 0.28 & 0.22 & 286.11 & 141.07 \\
#   220 &   4 & pop15 dpi pop15:ddpi pop75:ddpi & 0.28 & 0.22 & 286.14 & 141.10 \\
#   215 &   4 & pop15 dpi pop15:dpi pop15:ddpi & 0.28 & 0.22 & 286.16 & 141.11 \\
#   191 &   4 & pop15 pop75 pop15:pop75 pop75:dpi & 0.28 & 0.22 & 286.17 & 141.12 \\
#   258 &   4 & pop15 pop15:ddpi pop75:ddpi dpi:ddpi & 0.28 & 0.22 & 286.19 & 141.13 \\
#   212 &   4 & pop15 dpi pop15:pop75 pop75:dpi & 0.28 & 0.22 & 286.19 & 141.14 \\
#   241 &   4 & pop15 pop15:pop75 pop15:dpi pop75:dpi & 0.28 & 0.22 & 286.23 & 141.17 \\
#   216 &   4 & pop15 dpi pop15:dpi pop75:dpi & 0.28 & 0.22 & 286.23 & 141.17 \\
#   251 &   4 & pop15 pop15:dpi pop15:ddpi pop75:ddpi & 0.28 & 0.22 & 286.28 & 141.21 \\
#   377 &   4 & pop15:pop75 pop15:ddpi pop75:dpi pop75:ddpi & 0.28 & 0.22 & 286.29 & 141.22 \\
#   210 &   4 & pop15 dpi pop15:pop75 pop15:dpi & 0.28 & 0.21 & 286.56 & 141.45 \\
#   177 &   4 & pop15 pop75 dpi pop15:pop75 & 0.28 & 0.21 & 286.60 & 141.48 \\
#   300 &   4 & pop75 pop15:pop75 pop15:ddpi pop75:dpi & 0.28 & 0.21 & 286.60 & 141.49 \\
#   268 &   4 & pop75 dpi pop15:pop75 pop75:dpi & 0.28 & 0.21 & 286.67 & 141.54 \\
#   217 &   4 & pop15 dpi pop15:dpi pop75:ddpi & 0.28 & 0.21 & 286.68 & 141.55 \\
#   195 &   4 & pop15 pop75 pop15:dpi pop75:dpi & 0.28 & 0.21 & 286.68 & 141.55 \\
#   189 &   4 & pop15 pop75 pop15:pop75 pop15:dpi & 0.28 & 0.21 & 286.70 & 141.57 \\
#   180 &   4 & pop15 pop75 dpi pop75:dpi & 0.28 & 0.21 & 286.75 & 141.61 \\
#   178 &   4 & pop15 pop75 dpi pop15:dpi & 0.27 & 0.21 & 286.78 & 141.63 \\
#   314 &   4 & pop75 pop15:ddpi pop75:ddpi dpi:ddpi & 0.27 & 0.21 & 286.90 & 141.73 \\
#   322 &   4 & dpi ddpi pop15:dpi pop75:dpi & 0.27 & 0.20 & 287.32 & 142.09 \\
#   295 &   4 & pop75 ddpi pop75:ddpi dpi:ddpi & 0.27 & 0.20 & 287.38 & 142.14 \\
#   297 &   4 & pop75 pop15:pop75 pop15:dpi pop75:dpi & 0.26 & 0.19 & 287.88 & 142.57 \\
#   272 &   4 & pop75 dpi pop15:dpi pop75:dpi & 0.26 & 0.19 & 288.04 & 142.70 \\
#   267 &   4 & pop75 dpi pop15:pop75 pop15:ddpi & 0.26 & 0.19 & 288.11 & 142.76 \\
#   296 &   4 & pop75 pop15:pop75 pop15:dpi pop15:ddpi & 0.25 & 0.19 & 288.25 & 142.88 \\
#   333 &   4 & dpi pop15:pop75 pop15:dpi pop75:ddpi & 0.25 & 0.19 & 288.36 & 142.97 \\
#   319 &   4 & dpi ddpi pop15:pop75 pop75:ddpi & 0.25 & 0.18 & 288.43 & 143.03 \\
#   353 &   4 & ddpi pop15:pop75 pop15:dpi pop75:ddpi & 0.24 & 0.17 & 289.02 & 143.53 \\
#   358 &   4 & ddpi pop15:pop75 pop75:dpi pop75:ddpi & 0.24 & 0.17 & 289.08 & 143.58 \\
#   347 &   4 & dpi pop15:ddpi pop75:dpi pop75:ddpi & 0.23 & 0.17 & 289.54 & 143.98 \\
#   338 &   4 & dpi pop15:pop75 pop75:dpi pop75:ddpi & 0.23 & 0.16 & 289.68 & 144.09 \\
#   341 &   4 & dpi pop15:dpi pop15:ddpi pop75:dpi & 0.23 & 0.16 & 289.87 & 144.26 \\
#   342 &   4 & dpi pop15:dpi pop15:ddpi pop75:ddpi & 0.23 & 0.16 & 290.03 & 144.39 \\
#   332 &   4 & dpi pop15:pop75 pop15:dpi pop75:dpi & 0.23 & 0.16 & 290.07 & 144.42 \\
#   273 &   4 & pop75 dpi pop15:dpi pop75:ddpi & 0.23 & 0.16 & 290.10 & 144.45 \\
#   276 &   4 & pop75 dpi pop15:ddpi pop75:ddpi & 0.23 & 0.16 & 290.11 & 144.46 \\
#   323 &   4 & dpi ddpi pop15:dpi pop75:ddpi & 0.22 & 0.15 & 290.21 & 144.55 \\
#   374 &   4 & pop15:pop75 pop15:dpi pop75:dpi pop75:ddpi & 0.22 & 0.15 & 290.29 & 144.61 \\
#   312 &   4 & pop75 pop15:ddpi pop75:dpi pop75:ddpi & 0.22 & 0.15 & 290.35 & 144.67 \\
#   307 &   4 & pop75 pop15:dpi pop15:ddpi pop75:ddpi & 0.22 & 0.15 & 290.37 & 144.68 \\
#   261 &   4 & pop75 dpi ddpi pop15:dpi & 0.22 & 0.15 & 290.61 & 144.88 \\
#   316 &   4 & dpi ddpi pop15:pop75 pop15:dpi & 0.22 & 0.15 & 290.65 & 144.92 \\
#   381 &   4 & pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi & 0.21 & 0.15 & 290.76 & 145.02 \\
#   278 &   4 & pop75 dpi pop75:dpi pop75:ddpi & 0.21 & 0.14 & 290.84 & 145.09 \\
#   263 &   4 & pop75 dpi ddpi pop75:dpi & 0.21 & 0.14 & 291.12 & 145.32 \\
#   328 &   4 & dpi ddpi pop75:dpi pop75:ddpi & 0.21 & 0.14 & 291.19 & 145.38 \\
#   266 &   4 & pop75 dpi pop15:pop75 pop15:dpi & 0.20 & 0.13 & 291.67 & 145.79 \\
#   264 &   4 & pop75 dpi ddpi pop75:ddpi & 0.20 & 0.12 & 291.94 & 146.03 \\
#   293 &   4 & pop75 ddpi pop75:dpi pop75:ddpi & 0.19 & 0.12 & 292.08 & 146.14 \\
#   288 &   4 & pop75 ddpi pop15:dpi pop75:ddpi & 0.19 & 0.12 & 292.08 & 146.14 \\
#   309 &   4 & pop75 pop15:dpi pop75:dpi pop75:ddpi & 0.19 & 0.12 & 292.12 & 146.17 \\
#   364 &   4 & ddpi pop15:dpi pop75:dpi pop75:ddpi & 0.19 & 0.12 & 292.21 & 146.26 \\
#   287 &   4 & pop75 ddpi pop15:dpi pop75:dpi & 0.19 & 0.12 & 292.36 & 146.39 \\
#   271 &   4 & pop75 dpi pop15:dpi pop15:ddpi & 0.17 & 0.10 & 293.44 & 147.31 \\
#   275 &   4 & pop75 dpi pop15:ddpi pop75:dpi & 0.17 & 0.09 & 293.76 & 147.58 \\
#   331 &   4 & dpi pop15:pop75 pop15:dpi pop15:ddpi & 0.16 & 0.09 & 293.88 & 147.69 \\
#   352 &   4 & ddpi pop15:pop75 pop15:dpi pop75:dpi & 0.16 & 0.09 & 293.90 & 147.70 \\
#   318 &   4 & dpi ddpi pop15:pop75 pop75:dpi & 0.16 & 0.09 & 294.01 & 147.80 \\
#   306 &   4 & pop75 pop15:dpi pop15:ddpi pop75:dpi & 0.14 & 0.07 & 295.22 & 148.84 \\
#   371 &   4 & pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi & 0.09 & 0.01 & 297.88 & 151.14 \\
#   335 &   4 & dpi pop15:pop75 pop15:ddpi pop75:dpi & 0.09 & 0.01 & 298.21 & 151.43 \\
#   430 &   5 & pop15 pop75 pop15:pop75 pop75:dpi dpi:ddpi & 0.40 & 0.33 & 279.31 & 135.42 \\
#   456 &   5 & pop15 dpi ddpi pop75:ddpi dpi:ddpi & 0.40 & 0.33 & 279.38 & 135.48 \\
#   535 &   5 & pop75 dpi pop15:pop75 pop75:dpi dpi:ddpi & 0.40 & 0.33 & 279.55 & 135.61 \\
#   475 &   5 & pop15 dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.40 & 0.33 & 279.63 & 135.67 \\
#   555 &   5 & pop75 ddpi pop15:pop75 pop75:dpi dpi:ddpi & 0.40 & 0.33 & 279.64 & 135.68 \\
#   571 &   5 & pop75 pop15:pop75 pop15:dpi pop75:dpi dpi:ddpi & 0.40 & 0.33 & 279.65 & 135.69 \\
#   574 &   5 & pop75 pop15:pop75 pop15:ddpi pop75:dpi dpi:ddpi & 0.40 & 0.33 & 279.66 & 135.70 \\
#   485 &   5 & pop15 ddpi pop15:pop75 pop75:dpi dpi:ddpi & 0.40 & 0.33 & 279.67 & 135.71 \\
#   504 &   5 & pop15 pop15:pop75 pop15:ddpi pop75:dpi dpi:ddpi & 0.40 & 0.33 & 279.69 & 135.72 \\
#   465 &   5 & pop15 dpi pop15:pop75 pop75:dpi dpi:ddpi & 0.40 & 0.33 & 279.71 & 135.74 \\
#   501 &   5 & pop15 pop15:pop75 pop15:dpi pop75:dpi dpi:ddpi & 0.40 & 0.33 & 279.71 & 135.74 \\
#   446 &   5 & pop15 dpi ddpi pop15:pop75 dpi:ddpi & 0.39 & 0.33 & 279.78 & 135.79 \\
#   463 &   5 & pop15 dpi pop15:pop75 pop15:ddpi dpi:ddpi & 0.39 & 0.33 & 279.80 & 135.81 \\
#   576 &   5 & pop75 pop15:pop75 pop75:dpi pop75:ddpi dpi:ddpi & 0.39 & 0.32 & 279.82 & 135.83 \\
#   506 &   5 & pop15 pop15:pop75 pop75:dpi pop75:ddpi dpi:ddpi & 0.39 & 0.32 & 279.84 & 135.84 \\
#   460 &   5 & pop15 dpi pop15:pop75 pop15:dpi dpi:ddpi & 0.39 & 0.32 & 279.86 & 135.86 \\
#   496 &   5 & pop15 ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.39 & 0.32 & 279.96 & 135.93 \\
#   436 &   5 & pop15 pop75 pop15:dpi pop75:dpi dpi:ddpi & 0.39 & 0.32 & 280.00 & 135.97 \\
#   403 &   5 & pop15 pop75 dpi pop15:ddpi dpi:ddpi & 0.39 & 0.32 & 280.02 & 135.98 \\
#   391 &   5 & pop15 pop75 dpi ddpi dpi:ddpi & 0.39 & 0.32 & 280.02 & 135.98 \\
#   466 &   5 & pop15 dpi pop15:pop75 pop75:ddpi dpi:ddpi & 0.39 & 0.32 & 280.05 & 136.00 \\
#   396 &   5 & pop15 pop75 dpi pop15:pop75 dpi:ddpi & 0.39 & 0.32 & 280.06 & 136.01 \\
#   471 &   5 & pop15 dpi pop15:dpi pop75:dpi dpi:ddpi & 0.39 & 0.32 & 280.07 & 136.02 \\
#   511 &   5 & pop15 pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.39 & 0.32 & 280.08 & 136.03 \\
#   405 &   5 & pop15 pop75 dpi pop75:dpi dpi:ddpi & 0.39 & 0.32 & 280.09 & 136.04 \\
#   510 &   5 & pop15 pop15:dpi pop75:dpi pop75:ddpi dpi:ddpi & 0.39 & 0.32 & 280.15 & 136.09 \\
#   400 &   5 & pop15 pop75 dpi pop15:dpi dpi:ddpi & 0.39 & 0.32 & 280.19 & 136.12 \\
#   406 &   5 & pop15 pop75 dpi pop75:ddpi dpi:ddpi & 0.39 & 0.32 & 280.19 & 136.12 \\
#   508 &   5 & pop15 pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.39 & 0.32 & 280.23 & 136.15 \\
#   552 &   5 & pop75 ddpi pop15:pop75 pop15:ddpi pop75:ddpi & 0.39 & 0.32 & 280.24 & 136.16 \\
#   491 &   5 & pop15 ddpi pop15:dpi pop75:dpi dpi:ddpi & 0.39 & 0.32 & 280.24 & 136.16 \\
#   420 &   5 & pop15 pop75 ddpi pop75:dpi dpi:ddpi & 0.39 & 0.32 & 280.36 & 136.25 \\
#   439 &   5 & pop15 pop75 pop15:ddpi pop75:dpi dpi:ddpi & 0.39 & 0.32 & 280.37 & 136.26 \\
#   476 &   5 & pop15 dpi pop75:dpi pop75:ddpi dpi:ddpi & 0.39 & 0.32 & 280.38 & 136.27 \\
#   474 &   5 & pop15 dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.39 & 0.32 & 280.43 & 136.30 \\
#   455 &   5 & pop15 dpi ddpi pop75:dpi dpi:ddpi & 0.39 & 0.32 & 280.44 & 136.32 \\
#   482 &   5 & pop15 ddpi pop15:pop75 pop15:ddpi pop75:ddpi & 0.39 & 0.32 & 280.51 & 136.37 \\
#   415 &   5 & pop15 pop75 ddpi pop15:dpi dpi:ddpi & 0.39 & 0.32 & 280.53 & 136.38 \\
#   492 &   5 & pop15 ddpi pop15:dpi pop75:ddpi dpi:ddpi & 0.39 & 0.32 & 280.53 & 136.39 \\
#   494 &   5 & pop15 ddpi pop15:ddpi pop75:dpi dpi:ddpi & 0.38 & 0.31 & 280.57 & 136.42 \\
#   441 &   5 & pop15 pop75 pop75:dpi pop75:ddpi dpi:ddpi & 0.38 & 0.31 & 280.59 & 136.43 \\
#   434 &   5 & pop15 pop75 pop15:dpi pop15:ddpi dpi:ddpi & 0.38 & 0.31 & 280.60 & 136.44 \\
#   483 &   5 & pop15 ddpi pop15:pop75 pop15:ddpi dpi:ddpi & 0.38 & 0.31 & 280.70 & 136.52 \\
#   488 &   5 & pop15 ddpi pop15:dpi pop15:ddpi pop75:ddpi & 0.38 & 0.31 & 280.71 & 136.53 \\
#   481 &   5 & pop15 ddpi pop15:pop75 pop15:ddpi pop75:dpi & 0.38 & 0.31 & 280.75 & 136.56 \\
#   408 &   5 & pop15 pop75 ddpi pop15:pop75 pop15:ddpi & 0.38 & 0.31 & 280.75 & 136.56 \\
#   437 &   5 & pop15 pop75 pop15:dpi pop75:ddpi dpi:ddpi & 0.38 & 0.31 & 280.76 & 136.57 \\
#   443 &   5 & pop15 dpi ddpi pop15:pop75 pop15:ddpi & 0.38 & 0.31 & 280.77 & 136.58 \\
#   480 &   5 & pop15 ddpi pop15:pop75 pop15:dpi dpi:ddpi & 0.38 & 0.31 & 280.78 & 136.59 \\
#   477 &   5 & pop15 ddpi pop15:pop75 pop15:dpi pop15:ddpi & 0.38 & 0.31 & 280.78 & 136.59 \\
#   452 &   5 & pop15 dpi ddpi pop15:ddpi pop75:ddpi & 0.38 & 0.31 & 280.79 & 136.59 \\
#   495 &   5 & pop15 ddpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.38 & 0.31 & 280.81 & 136.61 \\
#   493 &   5 & pop15 ddpi pop15:ddpi pop75:dpi pop75:ddpi & 0.38 & 0.31 & 280.84 & 136.63 \\
#   425 &   5 & pop15 pop75 pop15:pop75 pop15:dpi dpi:ddpi & 0.38 & 0.31 & 280.86 & 136.65 \\
#   417 &   5 & pop15 pop75 ddpi pop15:ddpi pop75:ddpi & 0.38 & 0.31 & 280.88 & 136.66 \\
#   593 &   5 & dpi ddpi pop15:dpi pop15:ddpi pop75:ddpi & 0.38 & 0.31 & 280.89 & 136.67 \\
#   629 &   5 & ddpi pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.38 & 0.31 & 280.94 & 136.71 \\
#   499 &   5 & pop15 pop15:pop75 pop15:dpi pop15:ddpi dpi:ddpi & 0.38 & 0.31 & 280.94 & 136.71 \\
#   558 &   5 & pop75 ddpi pop15:dpi pop15:ddpi pop75:ddpi & 0.38 & 0.31 & 280.96 & 136.72 \\
#   551 &   5 & pop75 ddpi pop15:pop75 pop15:ddpi pop75:dpi & 0.38 & 0.31 & 280.96 & 136.73 \\
#   472 &   5 & pop15 dpi pop15:dpi pop75:ddpi dpi:ddpi & 0.38 & 0.31 & 281.04 & 136.79 \\
#   553 &   5 & pop75 ddpi pop15:pop75 pop15:ddpi dpi:ddpi & 0.38 & 0.31 & 281.06 & 136.81 \\
#   522 &   5 & pop75 dpi ddpi pop15:ddpi pop75:ddpi & 0.38 & 0.31 & 281.08 & 136.82 \\
#   513 &   5 & pop75 dpi ddpi pop15:pop75 pop15:ddpi & 0.38 & 0.31 & 281.10 & 136.84 \\
#   565 &   5 & pop75 ddpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.38 & 0.31 & 281.10 & 136.84 \\
#   547 &   5 & pop75 ddpi pop15:pop75 pop15:dpi pop15:ddpi & 0.38 & 0.31 & 281.10 & 136.84 \\
#   563 &   5 & pop75 ddpi pop15:ddpi pop75:dpi pop75:ddpi & 0.38 & 0.31 & 281.12 & 136.85 \\
#   627 &   5 & ddpi pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi & 0.38 & 0.31 & 281.16 & 136.89 \\
#   502 &   5 & pop15 pop15:pop75 pop15:dpi pop75:ddpi dpi:ddpi & 0.38 & 0.31 & 281.18 & 136.90 \\
#   541 &   5 & pop75 dpi pop15:dpi pop75:dpi dpi:ddpi & 0.38 & 0.31 & 281.22 & 136.94 \\
#   509 &   5 & pop15 pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.38 & 0.31 & 281.23 & 136.94 \\
#   600 &   5 & dpi ddpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.38 & 0.30 & 281.32 & 137.01 \\
#   418 &   5 & pop15 pop75 ddpi pop15:ddpi dpi:ddpi & 0.38 & 0.30 & 281.33 & 137.02 \\
#   469 &   5 & pop15 dpi pop15:dpi pop15:ddpi dpi:ddpi & 0.38 & 0.30 & 281.35 & 137.04 \\
#   450 &   5 & pop15 dpi ddpi pop15:dpi dpi:ddpi & 0.37 & 0.30 & 281.36 & 137.04 \\
#   598 &   5 & dpi ddpi pop15:ddpi pop75:dpi pop75:ddpi & 0.37 & 0.30 & 281.39 & 137.07 \\
#   453 &   5 & pop15 dpi ddpi pop15:ddpi dpi:ddpi & 0.37 & 0.30 & 281.40 & 137.07 \\
#   625 &   5 & ddpi pop15:pop75 pop15:ddpi pop75:ddpi dpi:ddpi & 0.37 & 0.30 & 281.40 & 137.08 \\
#   631 &   5 & ddpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.37 & 0.30 & 281.43 & 137.10 \\
#   623 &   5 & ddpi pop15:pop75 pop15:ddpi pop75:dpi pop75:ddpi & 0.37 & 0.30 & 281.47 & 137.13 \\
#   412 &   5 & pop15 pop75 ddpi pop15:dpi pop15:ddpi & 0.37 & 0.30 & 281.48 & 137.14 \\
#   388 &   5 & pop15 pop75 dpi ddpi pop15:ddpi & 0.37 & 0.30 & 281.52 & 137.17 \\
#   416 &   5 & pop15 pop75 ddpi pop15:ddpi pop75:dpi & 0.37 & 0.30 & 281.53 & 137.18 \\
#   587 &   5 & dpi ddpi pop15:pop75 pop15:ddpi pop75:ddpi & 0.37 & 0.30 & 281.56 & 137.21 \\
#   618 &   5 & ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi & 0.37 & 0.30 & 281.66 & 137.28 \\
#   582 &   5 & dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi & 0.37 & 0.30 & 281.69 & 137.31 \\
#   592 &   5 & dpi ddpi pop15:dpi pop15:ddpi pop75:dpi & 0.37 & 0.30 & 281.70 & 137.31 \\
#   619 &   5 & ddpi pop15:pop75 pop15:dpi pop15:ddpi dpi:ddpi & 0.37 & 0.30 & 281.71 & 137.32 \\
#   588 &   5 & dpi ddpi pop15:pop75 pop15:ddpi dpi:ddpi & 0.37 & 0.30 & 281.85 & 137.44 \\
#   624 &   5 & ddpi pop15:pop75 pop15:ddpi pop75:dpi dpi:ddpi & 0.37 & 0.30 & 281.86 & 137.44 \\
#   617 &   5 & ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi & 0.37 & 0.30 & 281.93 & 137.50 \\
#   586 &   5 & dpi ddpi pop15:pop75 pop15:ddpi pop75:dpi & 0.37 & 0.30 & 281.96 & 137.52 \\
#   530 &   5 & pop75 dpi pop15:pop75 pop15:dpi dpi:ddpi & 0.37 & 0.29 & 282.00 & 137.55 \\
#   489 &   5 & pop15 ddpi pop15:dpi pop15:ddpi dpi:ddpi & 0.37 & 0.29 & 282.00 & 137.56 \\
#   628 &   5 & ddpi pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.36 & 0.29 & 282.23 & 137.74 \\
#   559 &   5 & pop75 ddpi pop15:dpi pop15:ddpi dpi:ddpi & 0.36 & 0.29 & 282.29 & 137.78 \\
#   517 &   5 & pop75 dpi ddpi pop15:dpi pop15:ddpi & 0.36 & 0.29 & 282.32 & 137.81 \\
#   516 &   5 & pop75 dpi ddpi pop15:pop75 dpi:ddpi & 0.36 & 0.29 & 282.33 & 137.82 \\
#   606 &   5 & dpi pop15:pop75 pop15:dpi pop75:dpi dpi:ddpi & 0.36 & 0.29 & 282.40 & 137.87 \\
#   431 &   5 & pop15 pop75 pop15:pop75 pop75:ddpi dpi:ddpi & 0.36 & 0.29 & 282.42 & 137.89 \\
#   594 &   5 & dpi ddpi pop15:dpi pop15:ddpi dpi:ddpi & 0.36 & 0.29 & 282.43 & 137.90 \\
#   534 &   5 & pop75 dpi pop15:pop75 pop75:dpi pop75:ddpi & 0.36 & 0.29 & 282.48 & 137.94 \\
#   533 &   5 & pop75 dpi pop15:pop75 pop15:ddpi dpi:ddpi & 0.36 & 0.29 & 282.50 & 137.95 \\
#   566 &   5 & pop75 ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.36 & 0.29 & 282.50 & 137.96 \\
#   486 &   5 & pop15 ddpi pop15:pop75 pop75:ddpi dpi:ddpi & 0.36 & 0.29 & 282.52 & 137.97 \\
#   500 &   5 & pop15 pop15:pop75 pop15:dpi pop75:dpi pop75:ddpi & 0.36 & 0.29 & 282.56 & 138.00 \\
#   536 &   5 & pop75 dpi pop15:pop75 pop75:ddpi dpi:ddpi & 0.36 & 0.29 & 282.57 & 138.01 \\
#   599 &   5 & dpi ddpi pop15:ddpi pop75:dpi dpi:ddpi & 0.36 & 0.29 & 282.57 & 138.01 \\
#   464 &   5 & pop15 dpi pop15:pop75 pop75:dpi pop75:ddpi & 0.36 & 0.29 & 282.58 & 138.02 \\
#   564 &   5 & pop75 ddpi pop15:ddpi pop75:dpi dpi:ddpi & 0.36 & 0.29 & 282.59 & 138.02 \\
#   505 &   5 & pop15 pop15:pop75 pop15:ddpi pop75:ddpi dpi:ddpi & 0.36 & 0.29 & 282.62 & 138.05 \\
#   459 &   5 & pop15 dpi pop15:pop75 pop15:dpi pop75:ddpi & 0.36 & 0.29 & 282.63 & 138.06 \\
#   411 &   5 & pop15 pop75 ddpi pop15:pop75 dpi:ddpi & 0.36 & 0.29 & 282.64 & 138.07 \\
#   523 &   5 & pop75 dpi ddpi pop15:ddpi dpi:ddpi & 0.36 & 0.29 & 282.64 & 138.07 \\
#   514 &   5 & pop75 dpi ddpi pop15:pop75 pop75:dpi & 0.36 & 0.29 & 282.66 & 138.08 \\
#   451 &   5 & pop15 dpi ddpi pop15:ddpi pop75:dpi & 0.36 & 0.29 & 282.70 & 138.11 \\
#   615 &   5 & dpi pop15:dpi pop75:dpi pop75:ddpi dpi:ddpi & 0.36 & 0.28 & 282.82 & 138.20 \\
#   580 &   5 & pop75 pop15:dpi pop75:dpi pop75:ddpi dpi:ddpi & 0.36 & 0.28 & 282.85 & 138.23 \\
#   503 &   5 & pop15 pop15:pop75 pop15:ddpi pop75:dpi pop75:ddpi & 0.36 & 0.28 & 282.85 & 138.23 \\
#   484 &   5 & pop15 ddpi pop15:pop75 pop75:dpi pop75:ddpi & 0.36 & 0.28 & 282.85 & 138.23 \\
#   487 &   5 & pop15 ddpi pop15:dpi pop15:ddpi pop75:dpi & 0.36 & 0.28 & 282.86 & 138.24 \\
#   557 &   5 & pop75 ddpi pop15:dpi pop15:ddpi pop75:dpi & 0.36 & 0.28 & 282.87 & 138.25 \\
#   421 &   5 & pop15 pop75 ddpi pop75:ddpi dpi:ddpi & 0.36 & 0.28 & 282.87 & 138.25 \\
#   440 &   5 & pop15 pop75 pop15:ddpi pop75:ddpi dpi:ddpi & 0.36 & 0.28 & 282.89 & 138.27 \\
#   429 &   5 & pop15 pop75 pop15:pop75 pop75:dpi pop75:ddpi & 0.36 & 0.28 & 282.90 & 138.27 \\
#   570 &   5 & pop75 pop15:pop75 pop15:dpi pop75:dpi pop75:ddpi & 0.36 & 0.28 & 282.93 & 138.29 \\
#   596 &   5 & dpi ddpi pop15:dpi pop75:dpi dpi:ddpi & 0.35 & 0.28 & 282.95 & 138.31 \\
#   613 &   5 & dpi pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.35 & 0.28 & 282.96 & 138.32 \\
#   521 &   5 & pop75 dpi ddpi pop15:ddpi pop75:dpi & 0.35 & 0.28 & 282.99 & 138.35 \\
#   427 &   5 & pop15 pop75 pop15:pop75 pop15:ddpi pop75:ddpi & 0.35 & 0.28 & 283.04 & 138.39 \\
#   445 &   5 & pop15 dpi ddpi pop15:pop75 pop75:ddpi & 0.35 & 0.28 & 283.08 & 138.41 \\
#   447 &   5 & pop15 dpi ddpi pop15:dpi pop15:ddpi & 0.35 & 0.28 & 283.08 & 138.42 \\
#   395 &   5 & pop15 pop75 dpi pop15:pop75 pop75:ddpi & 0.35 & 0.28 & 283.09 & 138.42 \\
#   548 &   5 & pop75 ddpi pop15:pop75 pop15:dpi pop75:dpi & 0.35 & 0.28 & 283.09 & 138.42 \\
#   462 &   5 & pop15 dpi pop15:pop75 pop15:ddpi pop75:ddpi & 0.35 & 0.28 & 283.10 & 138.43 \\
#   410 &   5 & pop15 pop75 ddpi pop15:pop75 pop75:ddpi & 0.35 & 0.28 & 283.12 & 138.45 \\
#   409 &   5 & pop15 pop75 ddpi pop15:pop75 pop75:dpi & 0.35 & 0.28 & 283.13 & 138.45 \\
#   424 &   5 & pop15 pop75 pop15:pop75 pop15:dpi pop75:ddpi & 0.35 & 0.28 & 283.13 & 138.46 \\
#   478 &   5 & pop15 ddpi pop15:pop75 pop15:dpi pop75:dpi & 0.35 & 0.28 & 283.15 & 138.47 \\
#   479 &   5 & pop15 ddpi pop15:pop75 pop15:dpi pop75:ddpi & 0.35 & 0.28 & 283.16 & 138.48 \\
#   444 &   5 & pop15 dpi ddpi pop15:pop75 pop75:dpi & 0.35 & 0.28 & 283.17 & 138.48 \\
#   498 &   5 & pop15 pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi & 0.35 & 0.28 & 283.18 & 138.49 \\
#   442 &   5 & pop15 dpi ddpi pop15:pop75 pop15:dpi & 0.35 & 0.28 & 283.18 & 138.50 \\
#   578 &   5 & pop75 pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.35 & 0.28 & 283.30 & 138.59 \\
#   561 &   5 & pop75 ddpi pop15:dpi pop75:dpi dpi:ddpi & 0.35 & 0.28 & 283.37 & 138.65 \\
#   550 &   5 & pop75 ddpi pop15:pop75 pop15:dpi dpi:ddpi & 0.35 & 0.28 & 283.37 & 138.65 \\
#   581 &   5 & pop75 pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.35 & 0.27 & 283.43 & 138.69 \\
#   386 &   5 & pop15 pop75 dpi ddpi pop15:pop75 & 0.35 & 0.27 & 283.43 & 138.70 \\
#   526 &   5 & pop75 dpi ddpi pop75:ddpi dpi:ddpi & 0.35 & 0.27 & 283.46 & 138.72 \\
#   428 &   5 & pop15 pop75 pop15:pop75 pop15:ddpi dpi:ddpi & 0.35 & 0.27 & 283.52 & 138.76 \\
#   407 &   5 & pop15 pop75 ddpi pop15:pop75 pop15:dpi & 0.35 & 0.27 & 283.55 & 138.79 \\
#   572 &   5 & pop75 pop15:pop75 pop15:dpi pop75:ddpi dpi:ddpi & 0.35 & 0.27 & 283.63 & 138.86 \\
#   569 &   5 & pop75 pop15:pop75 pop15:dpi pop15:ddpi dpi:ddpi & 0.35 & 0.27 & 283.64 & 138.86 \\
#   562 &   5 & pop75 ddpi pop15:dpi pop75:ddpi dpi:ddpi & 0.35 & 0.27 & 283.66 & 138.88 \\
#   546 &   5 & pop75 dpi pop75:dpi pop75:ddpi dpi:ddpi & 0.34 & 0.27 & 283.71 & 138.92 \\
#   433 &   5 & pop15 pop75 pop15:dpi pop15:ddpi pop75:ddpi & 0.34 & 0.27 & 283.81 & 139.00 \\
#   402 &   5 & pop15 pop75 dpi pop15:ddpi pop75:ddpi & 0.34 & 0.27 & 283.82 & 139.01 \\
#   438 &   5 & pop15 pop75 pop15:ddpi pop75:dpi pop75:ddpi & 0.34 & 0.27 & 283.83 & 139.01 \\
#   414 &   5 & pop15 pop75 ddpi pop15:dpi pop75:ddpi & 0.34 & 0.27 & 283.87 & 139.04 \\
#   390 &   5 & pop15 pop75 dpi ddpi pop75:ddpi & 0.34 & 0.27 & 283.88 & 139.06 \\
#   419 &   5 & pop15 pop75 ddpi pop75:dpi pop75:ddpi & 0.34 & 0.27 & 283.88 & 139.06 \\
#   399 &   5 & pop15 pop75 dpi pop15:dpi pop75:ddpi & 0.34 & 0.27 & 283.89 & 139.06 \\
#   435 &   5 & pop15 pop75 pop15:dpi pop75:dpi pop75:ddpi & 0.34 & 0.27 & 283.90 & 139.07 \\
#   404 &   5 & pop15 pop75 dpi pop75:dpi pop75:ddpi & 0.34 & 0.27 & 283.91 & 139.08 \\
#   544 &   5 & pop75 dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.34 & 0.27 & 284.02 & 139.17 \\
#   525 &   5 & pop75 dpi ddpi pop75:dpi dpi:ddpi & 0.34 & 0.27 & 284.07 & 139.21 \\
#   531 &   5 & pop75 dpi pop15:pop75 pop15:ddpi pop75:dpi & 0.34 & 0.26 & 284.14 & 139.26 \\
#   413 &   5 & pop15 pop75 ddpi pop15:dpi pop75:dpi & 0.34 & 0.26 & 284.17 & 139.29 \\
#   387 &   5 & pop15 pop75 dpi ddpi pop15:dpi & 0.34 & 0.26 & 284.18 & 139.30 \\
#   389 &   5 & pop15 pop75 dpi ddpi pop75:dpi & 0.34 & 0.26 & 284.19 & 139.30 \\
#   637 &   5 & pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.34 & 0.26 & 284.32 & 139.41 \\
#   426 &   5 & pop15 pop75 pop15:pop75 pop15:ddpi pop75:dpi & 0.34 & 0.26 & 284.40 & 139.47 \\
#   497 &   5 & pop15 pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi & 0.34 & 0.26 & 284.41 & 139.48 \\
#   633 &   5 & pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.34 & 0.26 & 284.41 & 139.48 \\
#   461 &   5 & pop15 dpi pop15:pop75 pop15:ddpi pop75:dpi & 0.34 & 0.26 & 284.41 & 139.48 \\
#   542 &   5 & pop75 dpi pop15:dpi pop75:ddpi dpi:ddpi & 0.34 & 0.26 & 284.44 & 139.51 \\
#   457 &   5 & pop15 dpi pop15:pop75 pop15:dpi pop15:ddpi & 0.33 & 0.26 & 284.49 & 139.54 \\
#   579 &   5 & pop75 pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.33 & 0.26 & 284.50 & 139.56 \\
#   448 &   5 & pop15 dpi ddpi pop15:dpi pop75:dpi & 0.33 & 0.26 & 284.54 & 139.58 \\
#   635 &   5 & pop15:pop75 pop15:dpi pop75:dpi pop75:ddpi dpi:ddpi & 0.33 & 0.26 & 284.54 & 139.59 \\
#   621 &   5 & ddpi pop15:pop75 pop15:dpi pop75:dpi dpi:ddpi & 0.33 & 0.26 & 284.56 & 139.60 \\
#   539 &   5 & pop75 dpi pop15:dpi pop15:ddpi dpi:ddpi & 0.33 & 0.26 & 284.57 & 139.61 \\
#   630 &   5 & ddpi pop15:dpi pop75:dpi pop75:ddpi dpi:ddpi & 0.33 & 0.26 & 284.60 & 139.64 \\
#   520 &   5 & pop75 dpi ddpi pop15:dpi dpi:ddpi & 0.33 & 0.26 & 284.61 & 139.65 \\
#   545 &   5 & pop75 dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.33 & 0.26 & 284.62 & 139.65 \\
#   634 &   5 & pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.33 & 0.26 & 284.64 & 139.67 \\
#   614 &   5 & dpi pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.33 & 0.26 & 284.74 & 139.75 \\
#   604 &   5 & dpi pop15:pop75 pop15:dpi pop15:ddpi dpi:ddpi & 0.33 & 0.25 & 284.76 & 139.76 \\
#   597 &   5 & dpi ddpi pop15:dpi pop75:ddpi dpi:ddpi & 0.33 & 0.25 & 284.77 & 139.77 \\
#   622 &   5 & ddpi pop15:pop75 pop15:dpi pop75:ddpi dpi:ddpi & 0.33 & 0.25 & 284.78 & 139.78 \\
#   393 &   5 & pop15 pop75 dpi pop15:pop75 pop15:ddpi & 0.33 & 0.25 & 284.79 & 139.78 \\
#   585 &   5 & dpi ddpi pop15:pop75 pop15:dpi dpi:ddpi & 0.33 & 0.25 & 284.80 & 139.79 \\
#   607 &   5 & dpi pop15:pop75 pop15:dpi pop75:ddpi dpi:ddpi & 0.33 & 0.25 & 284.81 & 139.80 \\
# ...
#   924 &   7 & pop15 dpi pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.30 & 283.32 & 138.78 \\
#   870 &   7 & pop15 pop75 dpi pop15:pop75 pop15:dpi pop15:ddpi dpi:ddpi & 0.40 & 0.30 & 283.32 & 138.78 \\
#   851 &   7 & pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi dpi:ddpi & 0.40 & 0.30 & 283.33 & 138.79 \\
#   882 &   7 & pop15 pop75 dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.30 & 283.34 & 138.80 \\
#   863 &   7 & pop15 pop75 dpi ddpi pop15:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.30 & 283.34 & 138.80 \\
#   940 &   7 & pop75 dpi ddpi pop15:pop75 pop15:ddpi pop75:ddpi dpi:ddpi & 0.40 & 0.30 & 283.40 & 138.84 \\
#   950 &   7 & pop75 dpi pop15:pop75 pop15:dpi pop75:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.30 & 283.44 & 138.87 \\
#   920 &   7 & pop15 dpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.40 & 0.30 & 283.44 & 138.87 \\
#   911 &   7 & pop15 dpi ddpi pop15:pop75 pop15:ddpi pop75:dpi dpi:ddpi & 0.40 & 0.30 & 283.44 & 138.87 \\
#   908 &   7 & pop15 dpi ddpi pop15:pop75 pop15:dpi pop75:dpi dpi:ddpi & 0.40 & 0.30 & 283.45 & 138.87 \\
#   926 &   7 & pop15 ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.40 & 0.30 & 283.47 & 138.89 \\
#   876 &   7 & pop15 pop75 dpi pop15:pop75 pop15:ddpi pop75:ddpi dpi:ddpi & 0.40 & 0.30 & 283.47 & 138.89 \\
#   906 &   7 & pop15 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi dpi:ddpi & 0.40 & 0.30 & 283.51 & 138.92 \\
#   880 &   7 & pop15 pop75 dpi pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.40 & 0.30 & 283.51 & 138.92 \\
#   895 &   7 & pop15 pop75 ddpi pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.40 & 0.30 & 283.53 & 138.94 \\
#   927 &   7 & pop15 ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.40 & 0.30 & 283.54 & 138.94 \\
#   929 &   7 & pop15 ddpi pop15:pop75 pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.30 & 283.59 & 138.98 \\
#   958 &   7 & pop75 ddpi pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.30 & 283.63 & 139.01 \\
#   922 &   7 & pop15 dpi pop15:pop75 pop15:dpi pop75:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.30 & 283.65 & 139.02 \\
#   873 &   7 & pop15 pop75 dpi pop15:pop75 pop15:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.29 & 283.69 & 139.05 \\
#   897 &   7 & pop15 pop75 ddpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.29 & 283.70 & 139.06 \\
#   955 &   7 & pop75 ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.40 & 0.29 & 283.70 & 139.06 \\
#   938 &   7 & pop75 dpi ddpi pop15:pop75 pop15:ddpi pop75:dpi pop75:ddpi & 0.39 & 0.29 & 283.73 & 139.08 \\
#   854 &   7 & pop15 pop75 dpi ddpi pop15:pop75 pop15:ddpi dpi:ddpi & 0.39 & 0.29 & 283.76 & 139.10 \\
#   953 &   7 & pop75 ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi & 0.39 & 0.29 & 283.78 & 139.12 \\
#   894 &   7 & pop15 pop75 ddpi pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.39 & 0.29 & 283.86 & 139.17 \\
#   879 &   7 & pop15 pop75 dpi pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.39 & 0.29 & 283.86 & 139.18 \\
#   862 &   7 & pop15 pop75 dpi ddpi pop15:dpi pop75:dpi dpi:ddpi & 0.39 & 0.29 & 283.87 & 139.18 \\
#   944 &   7 & pop75 dpi ddpi pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.39 & 0.29 & 283.92 & 139.22 \\
#   865 &   7 & pop15 pop75 dpi ddpi pop15:ddpi pop75:dpi dpi:ddpi & 0.39 & 0.29 & 283.92 & 139.22 \\
#   889 &   7 & pop15 pop75 ddpi pop15:pop75 pop15:ddpi pop75:dpi pop75:ddpi & 0.39 & 0.29 & 283.96 & 139.25 \\
#   915 &   7 & pop15 dpi ddpi pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.39 & 0.29 & 283.98 & 139.26 \\
#   881 &   7 & pop15 pop75 dpi pop15:dpi pop75:dpi pop75:ddpi dpi:ddpi & 0.39 & 0.29 & 283.99 & 139.27 \\
#   860 &   7 & pop15 pop75 dpi ddpi pop15:dpi pop15:ddpi dpi:ddpi & 0.39 & 0.29 & 284.01 & 139.28 \\
#   945 &   7 & pop75 dpi ddpi pop15:dpi pop75:dpi pop75:ddpi dpi:ddpi & 0.39 & 0.29 & 284.01 & 139.28 \\
#   946 &   7 & pop75 dpi ddpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.39 & 0.29 & 284.04 & 139.30 \\
#   933 &   7 & pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi & 0.39 & 0.29 & 284.05 & 139.31 \\
#   853 &   7 & pop15 pop75 dpi ddpi pop15:pop75 pop15:ddpi pop75:ddpi & 0.39 & 0.29 & 284.09 & 139.34 \\
#   884 &   7 & pop15 pop75 ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi & 0.39 & 0.29 & 284.13 & 139.37 \\
#   891 &   7 & pop15 pop75 ddpi pop15:pop75 pop15:ddpi pop75:ddpi dpi:ddpi & 0.39 & 0.29 & 284.20 & 139.42 \\
#   852 &   7 & pop15 pop75 dpi ddpi pop15:pop75 pop15:ddpi pop75:dpi & 0.39 & 0.29 & 284.21 & 139.43 \\
#   932 &   7 & pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi & 0.39 & 0.29 & 284.22 & 139.43 \\
#   885 &   7 & pop15 pop75 ddpi pop15:pop75 pop15:dpi pop15:ddpi dpi:ddpi & 0.39 & 0.29 & 284.25 & 139.45 \\
#   883 &   7 & pop15 pop75 ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi & 0.39 & 0.29 & 284.26 & 139.46 \\
#   888 &   7 & pop15 pop75 ddpi pop15:pop75 pop15:dpi pop75:ddpi dpi:ddpi & 0.39 & 0.29 & 284.28 & 139.48 \\
#   905 &   7 & pop15 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi & 0.39 & 0.28 & 284.45 & 139.60 \\
#   925 &   7 & pop15 ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi & 0.39 & 0.28 & 284.46 & 139.61 \\
#   965 &   7 & dpi ddpi pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.39 & 0.28 & 284.47 & 139.62 \\
#   910 &   7 & pop15 dpi ddpi pop15:pop75 pop15:ddpi pop75:dpi pop75:ddpi & 0.39 & 0.28 & 284.47 & 139.62 \\
#   942 &   7 & pop75 dpi ddpi pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi & 0.39 & 0.28 & 284.48 & 139.62 \\
#   962 &   7 & dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.39 & 0.28 & 284.51 & 139.65 \\
#   934 &   7 & pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi dpi:ddpi & 0.39 & 0.28 & 284.52 & 139.65 \\
#   952 &   7 & pop75 dpi pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.39 & 0.28 & 284.52 & 139.65 \\
#   848 &   7 & pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi & 0.39 & 0.28 & 284.52 & 139.65 \\
#   914 &   7 & pop15 dpi ddpi pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi & 0.39 & 0.28 & 284.54 & 139.67 \\
#   900 &   7 & pop15 pop75 pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.39 & 0.28 & 284.54 & 139.67 \\
#   859 &   7 & pop15 pop75 dpi ddpi pop15:dpi pop15:ddpi pop75:ddpi & 0.38 & 0.28 & 284.58 & 139.69 \\
#   893 &   7 & pop15 pop75 ddpi pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi & 0.38 & 0.28 & 284.65 & 139.75 \\
#   967 &   7 & ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.38 & 0.28 & 284.73 & 139.80 \\
#   904 &   7 & pop15 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi & 0.38 & 0.28 & 284.73 & 139.80 \\
#   864 &   7 & pop15 pop75 dpi ddpi pop15:ddpi pop75:dpi pop75:ddpi & 0.38 & 0.28 & 284.75 & 139.82 \\
#   960 &   7 & dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi & 0.38 & 0.28 & 284.80 & 139.85 \\
#   937 &   7 & pop75 dpi ddpi pop15:pop75 pop15:dpi pop75:ddpi dpi:ddpi & 0.38 & 0.28 & 284.88 & 139.91 \\
#   943 &   7 & pop75 dpi ddpi pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.38 & 0.28 & 284.90 & 139.93 \\
#   961 &   7 & dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.38 & 0.28 & 285.03 & 140.02 \\
#   964 &   7 & dpi ddpi pop15:pop75 pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.38 & 0.27 & 285.15 & 140.11 \\
#   858 &   7 & pop15 pop75 dpi ddpi pop15:dpi pop15:ddpi pop75:dpi & 0.38 & 0.27 & 285.31 & 140.23 \\
#   949 &   7 & pop75 dpi pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.37 & 0.27 & 285.58 & 140.43 \\
#   886 &   7 & pop15 pop75 ddpi pop15:pop75 pop15:dpi pop75:dpi pop75:ddpi & 0.37 & 0.26 & 285.99 & 140.72 \\
#   855 &   7 & pop15 pop75 dpi ddpi pop15:pop75 pop75:dpi pop75:ddpi & 0.37 & 0.26 & 286.02 & 140.74 \\
#   871 &   7 & pop15 pop75 dpi pop15:pop75 pop15:dpi pop75:dpi pop75:ddpi & 0.37 & 0.26 & 286.06 & 140.77 \\
#   898 &   7 & pop15 pop75 pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi & 0.37 & 0.26 & 286.07 & 140.78 \\
#   874 &   7 & pop15 pop75 dpi pop15:pop75 pop15:ddpi pop75:dpi pop75:ddpi & 0.37 & 0.26 & 286.08 & 140.79 \\
#   849 &   7 & pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop75:dpi & 0.36 & 0.26 & 286.27 & 140.93 \\
#   963 &   7 & dpi ddpi pop15:pop75 pop15:dpi pop75:dpi pop75:ddpi dpi:ddpi & 0.36 & 0.26 & 286.34 & 140.98 \\
#   966 &   7 & dpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.36 & 0.26 & 286.35 & 140.99 \\
#   935 &   7 & pop75 dpi ddpi pop15:pop75 pop15:dpi pop75:dpi pop75:ddpi & 0.36 & 0.26 & 286.38 & 141.01 \\
#   850 &   7 & pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop75:ddpi & 0.36 & 0.26 & 286.41 & 141.03 \\
#   947 &   7 & pop75 dpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi & 0.36 & 0.25 & 286.44 & 141.06 \\
#   869 &   7 & pop15 pop75 dpi pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi & 0.36 & 0.25 & 286.46 & 141.07 \\
#   919 &   7 & pop15 dpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi & 0.36 & 0.25 & 286.47 & 141.08 \\
#   907 &   7 & pop15 dpi ddpi pop15:pop75 pop15:dpi pop75:dpi pop75:ddpi & 0.36 & 0.25 & 286.55 & 141.14 \\
#   868 &   7 & pop15 pop75 dpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi & 0.35 & 0.24 & 287.52 & 141.85 \\
#   878 &   7 & pop15 pop75 dpi pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi & 0.34 & 0.24 & 287.72 & 142.00 \\
#   861 &   7 & pop15 pop75 dpi ddpi pop15:dpi pop75:dpi pop75:ddpi & 0.34 & 0.23 & 287.79 & 142.05 \\
#   993 &   8 & pop15 pop75 ddpi pop15:pop75 pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.41 & 0.30 & 284.31 & 139.77 \\
#   992 &   8 & pop15 pop75 ddpi pop15:pop75 pop15:dpi pop75:dpi pop75:ddpi dpi:ddpi & 0.41 & 0.30 & 284.35 & 139.79 \\
#   977 &   8 & pop15 pop75 dpi ddpi pop15:pop75 pop75:dpi pop75:ddpi dpi:ddpi & 0.41 & 0.30 & 284.35 & 139.79 \\
#   1008 &   8 & pop75 dpi ddpi pop15:pop75 pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.41 & 0.30 & 284.35 & 139.80 \\
#   1011 &   8 & pop75 ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.41 & 0.30 & 284.38 & 139.81 \\
#   995 &   8 & pop15 pop75 pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.41 & 0.30 & 284.46 & 139.87 \\
#   987 &   8 & pop15 pop75 dpi pop15:pop75 pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.41 & 0.29 & 284.47 & 139.87 \\
#   1007 &   8 & pop75 dpi ddpi pop15:pop75 pop15:dpi pop75:dpi pop75:ddpi dpi:ddpi & 0.41 & 0.29 & 284.49 & 139.89 \\
#   1010 &   8 & pop75 dpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.41 & 0.29 & 284.72 & 140.05 \\
#   973 &   8 & pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop75:ddpi dpi:ddpi & 0.41 & 0.29 & 284.86 & 140.14 \\
#   990 &   8 & pop15 pop75 ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.41 & 0.29 & 284.87 & 140.15 \\
#   984 &   8 & pop15 pop75 dpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.41 & 0.29 & 284.88 & 140.16 \\
#   975 &   8 & pop15 pop75 dpi ddpi pop15:pop75 pop15:ddpi pop75:dpi dpi:ddpi & 0.41 & 0.29 & 284.88 & 140.16 \\
#   972 &   8 & pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop75:dpi dpi:ddpi & 0.40 & 0.29 & 284.90 & 140.17 \\
#   985 &   8 & pop15 pop75 dpi pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.40 & 0.29 & 285.00 & 140.24 \\
#   994 &   8 & pop15 pop75 ddpi pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.29 & 285.01 & 140.25 \\
#   976 &   8 & pop15 pop75 dpi ddpi pop15:pop75 pop15:ddpi pop75:ddpi dpi:ddpi & 0.40 & 0.29 & 285.02 & 140.26 \\
#   981 &   8 & pop15 pop75 dpi ddpi pop15:dpi pop75:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.29 & 285.10 & 140.31 \\
#   1005 &   8 & pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.40 & 0.29 & 285.11 & 140.31 \\
#   982 &   8 & pop15 pop75 dpi ddpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.29 & 285.12 & 140.32 \\
#   1000 &   8 & pop15 dpi ddpi pop15:pop75 pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.29 & 285.14 & 140.33 \\
#   1001 &   8 & pop15 dpi ddpi pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.29 & 285.16 & 140.35 \\
#   1003 &   8 & pop15 ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.29 & 285.16 & 140.35 \\
#   999 &   8 & pop15 dpi ddpi pop15:pop75 pop15:dpi pop75:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.29 & 285.17 & 140.35 \\
#   998 &   8 & pop15 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.40 & 0.29 & 285.17 & 140.36 \\
#   980 &   8 & pop15 pop75 dpi ddpi pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.40 & 0.28 & 285.21 & 140.38 \\
#   1009 &   8 & pop75 dpi ddpi pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.28 & 285.23 & 140.40 \\
#   986 &   8 & pop15 pop75 dpi pop15:pop75 pop15:dpi pop75:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.28 & 285.23 & 140.40 \\
#   1002 &   8 & pop15 dpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.28 & 285.23 & 140.40 \\
#   1006 &   8 & pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.40 & 0.28 & 285.26 & 140.42 \\
#   988 &   8 & pop15 pop75 dpi pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.28 & 285.27 & 140.42 \\
#   970 &   8 & pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi dpi:ddpi & 0.40 & 0.28 & 285.32 & 140.46 \\
#   997 &   8 & pop15 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.40 & 0.28 & 285.43 & 140.54 \\
#   991 &   8 & pop15 pop75 ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.40 & 0.28 & 285.50 & 140.58 \\
#   974 &   8 & pop15 pop75 dpi ddpi pop15:pop75 pop15:ddpi pop75:dpi pop75:ddpi & 0.40 & 0.28 & 285.70 & 140.72 \\
#   1004 &   8 & pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi & 0.39 & 0.28 & 285.73 & 140.74 \\
#   989 &   8 & pop15 pop75 ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi & 0.39 & 0.28 & 285.78 & 140.78 \\
#   979 &   8 & pop15 pop75 dpi ddpi pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.39 & 0.28 & 285.86 & 140.83 \\
#   969 &   8 & pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi & 0.39 & 0.27 & 286.02 & 140.94 \\
#   968 &   8 & pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi & 0.39 & 0.27 & 286.21 & 141.07 \\
#   1012 &   8 & dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.39 & 0.27 & 286.27 & 141.11 \\
#   996 &   8 & pop15 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi & 0.39 & 0.27 & 286.45 & 141.24 \\
#   978 &   8 & pop15 pop75 dpi ddpi pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi & 0.39 & 0.27 & 286.48 & 141.26 \\
#   971 &   8 & pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop75:dpi pop75:ddpi & 0.37 & 0.24 & 287.97 & 142.30 \\
#   983 &   8 & pop15 pop75 dpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi & 0.37 & 0.24 & 288.04 & 142.35 \\
#   1017 &   9 & pop15 pop75 dpi ddpi pop15:pop75 pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.41 & 0.28 & 286.30 & 141.47 \\
#   1020 &   9 & pop15 pop75 ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.41 & 0.28 & 286.30 & 141.47 \\
#   1022 &   9 & pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.41 & 0.28 & 286.34 & 141.50 \\
#   1016 &   9 & pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop75:dpi pop75:ddpi dpi:ddpi & 0.41 & 0.28 & 286.35 & 141.50 \\
#   1019 &   9 & pop15 pop75 dpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.41 & 0.28 & 286.46 & 141.58 \\
#   1015 &   9 & pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:ddpi dpi:ddpi & 0.41 & 0.27 & 286.78 & 141.78 \\
#   1014 &   9 & pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi dpi:ddpi & 0.41 & 0.27 & 286.87 & 141.84 \\
#   1018 &   9 & pop15 pop75 dpi ddpi pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.27 & 286.99 & 141.92 \\
#   1021 &   9 & pop15 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.40 & 0.27 & 287.13 & 142.01 \\
#   1013 &   9 & pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi & 0.40 & 0.26 & 287.69 & 142.38 \\
#   1023 &  10 & pop15 pop75 dpi ddpi pop15:pop75 pop15:dpi pop15:ddpi pop75:dpi pop75:ddpi dpi:ddpi & 0.41 & 0.26 & 288.30 & 143.18 \\
#    \hline
# \end{tabular}
# \end{table}

# %%
# select model with max adjusted r^2, lowest aic, and lowest bic
which.max(all_possible_second_order_models$adjr)
which.min(all_possible_second_order_models$aic)
which.min(all_possible_second_order_models$sbic)
# Out:
# [1] 56
# [1] 56
# [1] 56

# %%
all_possible_second_order_models[56, ]
# Out:
#    mindex n predictors               rsquare   adjr     predrsq  cp
# 90 56     3 pop15 pop75:dpi dpi:ddpi 0.3827636 0.342509 0.286492 -1.060724
#    aic      sbic     sbc      msep     fpe      apc       hsp
# 90 276.7299 133.2859 286.2901 14.35997 14.25438 0.7245819 0.2933001

# %%
models.second_order_optimal = lm(sr ~ (pop15 + pop75:dpi + dpi:ddpi), data = LifeCycleSavings)
summary(models.second_order_optimal)

# xtable
print.summary.lm.xtable(summary(models.second_order_optimal))
# Out:
# Call:
# lm(formula = sr ~ (pop15 + pop75:dpi + dpi:ddpi), data = LifeCycleSavings)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.2680 -2.5999 -0.0505  2.1913 11.2728
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) 17.7286255  4.3857223   4.042  0.00020 ***
# pop15       -0.2420065  0.1008862  -2.399  0.02056 *
# pop75:dpi   -0.0007351  0.0002336  -3.147  0.00290 **
# dpi:ddpi     0.0007965  0.0002633   3.025  0.00406 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 3.633 on 46 degrees of freedom
# Multiple R-squared:  0.3828,	Adjusted R-squared:  0.3425
# F-statistic: 9.509 on 3 and 46 DF,  p-value: 5.322e-05
# \begin{verbatim}
# Call:
# lm(formula = sr ~ (pop15 + pop75:dpi + dpi:ddpi), data = LifeCycleSavings)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.2680 -2.5999 -0.0505  2.1913 11.2728
# \end{verbatim}% latex table generated in R 3.4.3 by xtable 1.8-2 package
# % Sun Apr 08 17:25:45 2018
# \begin{table}[ht]
# \begin{left}
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Pr($>$$|$t$|$) \\
#   \hline
# (Intercept) & 17.7286 & 4.3857 & 4.04 & 0.0002 \\
#   pop15 & -0.2420 & 0.1009 & -2.40 & 0.0206 \\
#   pop75:dpi & -0.0007 & 0.0002 & -3.15 & 0.0029 \\
#   dpi:ddpi & 0.0008 & 0.0003 & 3.03 & 0.0041 \\
#    \hline
# \end{tabular}
# \end{left}
# \end{table}
# \begin{verbatim}Residual standard error: 3.633 on 46 degrees of freedom
# Multiple R-squared: 0.3828,	Adjusted R-squared: 0.3425
# F-statistic: 9.509 on 3 and 46 DF,  p-value: 5.322e-05
#
# \end{verbatim}

# %% [markdown]
# ### Inspect for collinearity issues

# %%
# detect multi-collinearity
require(car)

vif(models.baseline)
vif(models.baseline_optimal)
vif(models.second_order_optimal)
# Out:
#    pop15    pop75      dpi     ddpi
# 5.937661 6.629105 2.884369 1.074309
#    pop15    pop75     ddpi
# 5.745478 5.736014 1.004186
#     pop15 pop75:dpi  dpi:ddpi
#  3.164763  3.345982  3.196165

# %%
# try excluding one of pop15 and pop75
vif(lm(sr ~ pop15 + pop75 + dpi + ddpi , data=LifeCycleSavings))
vif(lm(sr ~ pop75 + dpi + ddpi , data=LifeCycleSavings))
vif(lm(sr ~ pop15 + dpi + ddpi , data=LifeCycleSavings))
# Out:
#    pop15    pop75      dpi     ddpi
# 5.937661 6.629105 2.884369 1.074309
#    pop75      dpi     ddpi
# 2.745976 2.791011 1.063029
#    pop15      dpi     ddpi
# 2.459559 2.495779 1.071092

# %%
# backward elimination without pop15
models.baseline_without_pop15_backward <-step(lm(sr ~ pop75 + dpi + ddpi, data = LifeCycleSavings))

# xtable
print.summary.lm.xtable(summary(models.baseline_without_pop15_backward))
# Out:
# Start:  AIC=146.49
# sr ~ pop75 + dpi + ddpi
#
#         Df Sum of Sq    RSS    AIC
# - dpi    1     0.670 798.40 144.53
# - pop75  1    26.993 824.72 146.15
# <none>               797.72 146.49
# - ddpi   1    85.223 882.95 149.56
#
# Step:  AIC=144.53
# sr ~ pop75 + ddpi
#
#         Df Sum of Sq    RSS    AIC
# <none>               798.40 144.53
# - ddpi   1    86.688 885.08 147.68
# - pop75  1    93.859 892.25 148.09
# \begin{verbatim}
# Call:
# lm(formula = sr ~ pop75 + ddpi, data = LifeCycleSavings)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.0223 -3.2949  0.0889  2.4570 10.1069
# \end{verbatim}% latex table generated in R 3.4.3 by xtable 1.8-2 package
# % Sun Apr 08 17:28:05 2018
# \begin{table}[ht]
# \begin{left}
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Pr($>$$|$t$|$) \\
#   \hline
# (Intercept) & 5.4695 & 1.4101 & 3.88 & 0.0003 \\
#   pop75 & 1.0726 & 0.4563 & 2.35 & 0.0230 \\
#   ddpi & 0.4636 & 0.2052 & 2.26 & 0.0286 \\
#    \hline
# \end{tabular}
# \end{left}
# \end{table}
# \begin{verbatim}Residual standard error: 4.122 on 47 degrees of freedom
# Multiple R-squared: 0.1883,	Adjusted R-squared: 0.1538
# F-statistic: 5.452 on 2 and 47 DF,  p-value: 0.007423
#
# \end{verbatim}

# %%
# backward elimination without pop75
models.baseline_without_pop75_backward <-step(lm(sr ~ pop15 + dpi + ddpi, data = LifeCycleSavings))
summary(models.baseline_without_pop75_backward)

# xtable
print.summary.lm.xtable(summary(models.baseline_without_pop75_backward))
# Out:
# Start:  AIC=138.94
# sr ~ pop15 + dpi + ddpi
#
#         Df Sum of Sq    RSS    AIC
# - dpi    1    14.603 700.55 137.99
# <none>               685.95 138.94
# - ddpi   1    58.175 744.12 141.01
# - pop15  1   138.769 824.72 146.15
#
# Step:  AIC=137.99
# sr ~ pop15 + ddpi
#
#         Df Sum of Sq    RSS    AIC
# <none>               700.55 137.99
# - ddpi   1    78.959 779.51 141.33
# - pop15  1   191.702 892.25 148.09
# Call:
# lm(formula = sr ~ pop15 + ddpi, data = LifeCycleSavings)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.5831 -2.8632  0.0453  2.2273 10.4753
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 15.59958    2.33439   6.682 2.48e-08 ***
# pop15       -0.21638    0.06033  -3.586 0.000796 ***
# ddpi         0.44283    0.19240   2.302 0.025837 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 3.861 on 47 degrees of freedom
# Multiple R-squared:  0.2878,	Adjusted R-squared:  0.2575
# F-statistic: 9.496 on 2 and 47 DF,  p-value: 0.0003438
# \begin{verbatim}
# Call:
# lm(formula = sr ~ pop15 + ddpi, data = LifeCycleSavings)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.5831 -2.8632  0.0453  2.2273 10.4753
# \end{verbatim}% latex table generated in R 3.4.3 by xtable 1.8-2 package
# % Sun Apr 08 17:29:23 2018
# \begin{table}[ht]
# \begin{left}
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Pr($>$$|$t$|$) \\
#   \hline
# (Intercept) & 15.5996 & 2.3344 & 6.68 & 0.0000 \\
#   pop15 & -0.2164 & 0.0603 & -3.59 & 0.0008 \\
#   ddpi & 0.4428 & 0.1924 & 2.30 & 0.0258 \\
#    \hline
# \end{tabular}
# \end{left}
# \end{table}
# \begin{verbatim}Residual standard error: 3.861 on 47 degrees of freedom
# Multiple R-squared: 0.2878,	Adjusted R-squared: 0.2575
# F-statistic: 9.496 on 2 and 47 DF,  p-value: 0.0003438
#
# \end{verbatim}

# %%
# summary(models.baseline)
# summary(models.baseline_without_pop15_backward)
# summary(models.baseline_without_pop75_backward)
# summary(models.baseline_optimal)
# summary(models.second_order_optimal)

ls_models = list(models.baseline, 
          models.baseline_without_pop15_backward,
          models.baseline_without_pop75_backward,
          models.baseline_optimal,
          models.second_order_optimal
          )

ls_names = c(
            "1stOrderBase",
            "1stOrder w/o pop15",
            "1stOrder w/o pop75 ",
            "1stOrderBest",
            "2ndOrderBest"
            )

print(screenreg(l = ls_models, custom.model.names = ls_names))

# latex format
print(texreg(l = ls_models, custom.model.names = ls_names))
# Out:
# ==============================================================================================
#              1stOrderBase  1stOrder w/o pop15  1stOrder w/o pop75   1stOrderBest  2ndOrderBest
# ----------------------------------------------------------------------------------------------
# (Intercept)  28.57 ***      5.47 ***           15.60 ***            28.12 ***     17.73 ***
#              (7.35)        (1.41)              (2.33)               (7.18)        (4.39)
# pop15        -0.46 **                          -0.22 ***            -0.45 **      -0.24 *
#              (0.14)                            (0.06)               (0.14)        (0.10)
# pop75        -1.69          1.07 *                                  -1.84
#              (1.08)        (0.46)                                   (1.00)
# dpi          -0.00
#              (0.00)
# ddpi          0.41 *        0.46 *              0.44 *               0.43 *
#              (0.20)        (0.21)              (0.19)               (0.19)
# pop75:dpi                                                                         -0.00 **
#                                                                                   (0.00)
# dpi:ddpi                                                                           0.00 **
#                                                                                   (0.00)
# ----------------------------------------------------------------------------------------------
# R^2           0.34          0.19                0.29                 0.34          0.38
# Adj. R^2      0.28          0.15                0.26                 0.29          0.34
# Num. obs.    50            50                  50                   50            50
# RMSE          3.80          4.12                3.86                 3.77          3.63
# ==============================================================================================
# *** p < 0.001, ** p < 0.01, * p < 0.05
#
# \begin{table}
# \begin{center}
# \begin{tabular}{l c c c c c }
# \hline
#  & 1stOrderBase & 1stOrder w/o pop15 & 1stOrder w/o pop75  & 1stOrderBest & 2ndOrderBest \\
# \hline
# (Intercept) & $28.57^{***}$ & $5.47^{***}$ & $15.60^{***}$ & $28.12^{***}$ & $17.73^{***}$ \\
#             & $(7.35)$      & $(1.41)$     & $(2.33)$      & $(7.18)$      & $(4.39)$      \\
# pop15       & $-0.46^{**}$  &              & $-0.22^{***}$ & $-0.45^{**}$  & $-0.24^{*}$   \\
#             & $(0.14)$      &              & $(0.06)$      & $(0.14)$      & $(0.10)$      \\
# pop75       & $-1.69$       & $1.07^{*}$   &               & $-1.84$       &               \\
#             & $(1.08)$      & $(0.46)$     &               & $(1.00)$      &               \\
# dpi         & $-0.00$       &              &               &               &               \\
#             & $(0.00)$      &              &               &               &               \\
# ddpi        & $0.41^{*}$    & $0.46^{*}$   & $0.44^{*}$    & $0.43^{*}$    &               \\
#             & $(0.20)$      & $(0.21)$     & $(0.19)$      & $(0.19)$      &               \\
# pop75:dpi   &               &              &               &               & $-0.00^{**}$  \\
#             &               &              &               &               & $(0.00)$      \\
# dpi:ddpi    &               &              &               &               & $0.00^{**}$   \\
#             &               &              &               &               & $(0.00)$      \\
# \hline
# R$^2$       & 0.34          & 0.19         & 0.29          & 0.34          & 0.38          \\
# Adj. R$^2$  & 0.28          & 0.15         & 0.26          & 0.29          & 0.34          \\
# Num. obs.   & 50            & 50           & 50            & 50            & 50            \\
# RMSE        & 3.80          & 4.12         & 3.86          & 3.77          & 3.63          \\
# \hline
# \multicolumn{6}{l}{\scriptsize{$^{***}p<0.001$, $^{**}p<0.01$, $^*p<0.05$}}
# \end{tabular}
# \caption{Statistical models}
# \label{table:coefficients}
# \end{center}
# \end{table}

# %% [markdown]
# # Diagnostics
#
# ### baseline_optimal

# %%
# pdf("LifeCycleSavings_baseline_optimal_diagnostic.pdf", height = 7, width = 7)

layout(matrix(1:2,ncol=2))
plot(models.baseline_optimal, which = 1)
plot(models.baseline_optimal, which = 2)


layout(matrix(1:2,ncol=2))
plot(models.baseline_optimal, which = 3)
plot(models.baseline_optimal, which = 4)

# Saving the plot
# dev.off()
# Out:
# Plot with title ""
# Plot with title ""

# %% [markdown]
# ### baseline_without_pop75_backward

# %%
# pdf("LifeCycleSavings_baseline_without_pop75_backward.pdf", height = 7, width = 7)

layout(matrix(1:2,ncol=2))
plot(models.baseline_without_pop75_backward, which = 1)
plot(models.baseline_without_pop75_backward, which = 2)
layout(matrix(1:2,ncol=2))
plot(models.baseline_without_pop75_backward, which = 3)
plot(models.baseline_without_pop75_backward, which = 4)

# Saving the plot
# dev.off()
# Out:
# Plot with title ""
# Plot with title ""

# %% [markdown]
# ### baseline_without_pop15_backward

# %%
# pdf("LifeCycleSavings_baseline_without_pop15_backward.pdf", height = 7, width = 7)

layout(matrix(1:2,ncol=2))
plot(models.baseline_without_pop15_backward, which = 1)
plot(models.baseline_without_pop15_backward, which = 2)
layout(matrix(1:2,ncol=2))
plot(models.baseline_without_pop15_backward, which = 3)
plot(models.baseline_without_pop15_backward, which = 4)

# Saving the plot
# dev.off()
# Out:
# Plot with title ""
# Plot with title ""

# %% [markdown]
# ### second_order_optimal

# %%
# pdf("LifeCycleSavings_second_order_optimal.pdf", height = 7, width = 7)

layout(matrix(1:2,ncol=2))
plot(models.second_order_optimal, which = 1)
plot(models.second_order_optimal, which = 2)
layout(matrix(1:2,ncol=2))
plot(models.second_order_optimal, which = 3)
plot(models.second_order_optimal, which = 4)

# Saving the plot
# dev.off()
# Out:
# Plot with title ""
# Plot with title ""

# %% [markdown]
# # Remove outliers for baseline_without_pop75_backward

# %%
which(rownames(LifeCycleSavings) %in% c("Libya", "Chile", "Zambia", "Japan"))
# Out:
# [1]  7 23 46 49

# %%
LifeCycleSavings.without_Libya = LifeCycleSavings[-c(49, 7, 23, 46), ]

# %%
str(LifeCycleSavings.without_Libya)
# Out:
# 'data.frame':	46 obs. of  5 variables:
#  $ sr   : num  11.43 12.07 13.17 5.75 12.88 ...
#  $ pop15: num  29.4 23.3 23.8 41.9 42.2 ...
#  $ pop75: num  2.87 4.41 4.43 1.67 0.83 2.85 0.67 1.06 1.14 3.93 ...
#  $ dpi  : num  2330 1508 2108 189 728 ...
#  $ ddpi : num  2.87 3.93 3.82 0.22 4.56 2.43 6.51 3.08 2.8 3.99 ...

# %%
models.baseline_without_pop75_backward_revised = step(lm(sr ~ pop15 + dpi + ddpi, data = LifeCycleSavings.without_Libya))
summary(models.baseline_without_pop75_backward_revised)

print.summary.lm.xtable(summary(models.baseline_without_pop75_backward_revised))
# Out:
# Start:  AIC=112.12
# sr ~ pop15 + dpi + ddpi
#
#         Df Sum of Sq    RSS    AIC
# - dpi    1     8.817 451.20 111.03
# <none>               442.38 112.12
# - ddpi   1    29.269 471.65 113.07
# - pop15  1   108.783 551.16 120.24
#
# Step:  AIC=111.03
# sr ~ pop15 + ddpi
#
#         Df Sum of Sq    RSS    AIC
# <none>               451.20 111.03
# - ddpi   1    41.132 492.33 113.04
# - pop15  1   161.604 612.80 123.11
# Call:
# lm(formula = sr ~ pop15 + ddpi, data = LifeCycleSavings.without_Libya)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.3033 -2.4520  0.1975  1.7263  6.4475
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 15.15557    2.17175   6.979 1.38e-08 ***
# pop15       -0.20835    0.05309  -3.924 0.000309 ***
# ddpi         0.45342    0.22901   1.980 0.054140 .
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 3.239 on 43 degrees of freedom
# Multiple R-squared:  0.3449,	Adjusted R-squared:  0.3144
# F-statistic: 11.32 on 2 and 43 DF,  p-value: 0.0001125
# \begin{verbatim}
# Call:
# lm(formula = sr ~ pop15 + ddpi, data = LifeCycleSavings.without_Libya)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.3033 -2.4520  0.1975  1.7263  6.4475
# \end{verbatim}% latex table generated in R 3.4.3 by xtable 1.8-2 package
# % Mon Apr 09 03:58:21 2018
# \begin{table}[ht]
# \begin{left}
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Pr($>$$|$t$|$) \\
#   \hline
# (Intercept) & 15.1556 & 2.1717 & 6.98 & 0.0000 \\
#   pop15 & -0.2083 & 0.0531 & -3.92 & 0.0003 \\
#   ddpi & 0.4534 & 0.2290 & 1.98 & 0.0541 \\
#    \hline
# \end{tabular}
# \end{left}
# \end{table}
# \begin{verbatim}Residual standard error: 3.239 on 43 degrees of freedom
# Multiple R-squared: 0.3449,	Adjusted R-squared: 0.3144
# F-statistic: 11.32 on 2 and 43 DF,  p-value: 0.0001125
#
# \end{verbatim}

# %%
pdf("LifeCycleSavings_final_model_without_outliers.pdf", height = 7, width = 7)

layout(matrix(1:2,ncol=2))
plot(models.baseline_without_pop75_backward_revised, which = 1)
plot(models.baseline_without_pop75_backward_revised, which = 2)
layout(matrix(1:2,ncol=2))
plot(models.baseline_without_pop75_backward_revised, which = 3)
plot(models.baseline_without_pop75_backward_revised, which = 4)

# Saving the plot
dev.off()
# Out:
# png
#   2

# %%
#
